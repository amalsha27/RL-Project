# %% [markdown]
# ### Standard PPO

# %%
import random
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from collections import deque
from sklearn.model_selection import train_test_split
import h5py
from sklearn.model_selection import KFold
import json

# %%
#  Data Preprocessing Function

def preprocess_data(df):
    # Derive occupancy from lights (1 if lights > 0, else 0).
    df['Occupancy'] = df['lights'].apply(lambda x: 1 if x > 0 else 0)
    
    # Compute the average indoor temperature from columns T1 to T9.
    temp_cols = [f'T{i}' for i in range(1, 10)]
    df['Avg_T1_T9'] = df[temp_cols].mean(axis=1)
    
    # Compute HVAC energy consumption (Appliances minus lights).
    df['HVAC_energy'] = df['Appliances'] - df['lights']
    
    # Extract hour of day from the date column.
    df['date'] = pd.to_datetime(df['date'])
    df['Hour_of_day'] = df['date'].dt.hour
    
    # Select only the relevant features.
    relevant_features = ['Avg_T1_T9', 'T_out', 'Occupancy', 'Hour_of_day', 'HVAC_energy']
    df = df[relevant_features].copy()
    
    # Forward-fill any missing values.
    df.ffill(inplace=True)
    return df

# %%
# HVAC Environment with Dynamic Temperature and Scaled Reward

class HVACEnvironment:
    def __init__(self, dataframe, desired_temperature=22):
        self.df = dataframe.copy()
        self.desired_temperature = desired_temperature  
        self.observation_space_shape = self.df.shape[1]  # number of features
        self.action_space_n = 4  # 0 = Off, 1 = Low, 2 = Medium, 3 = High
        self.current_step = 0
        self.max_steps = len(self.df) - 1
        
        # Determine energy thresholds (for simulation purposes)
        self.energy_thresholds = {
            'Low': self.df['HVAC_energy'].quantile(0.25),
            'Medium': self.df['HVAC_energy'].quantile(0.5),
            'High': self.df['HVAC_energy'].quantile(0.75)
        }
        # Initialize a mutable indoor temperature.
        self.current_temp = self.df['Avg_T1_T9'].iloc[0]

    def reset(self, start_step=0):
        self.current_step = start_step
        # Reset the indoor temperature.
        self.current_temp = self.df['Avg_T1_T9'].iloc[self.current_step]
        return self._get_state()

    def _get_state(self):
        # Use the updated current_temp in place of the fixed dataset value.
        row = self.df.iloc[self.current_step].copy()
        row['Avg_T1_T9'] = self.current_temp
        return row.values

    def _get_reward(self, action, simulated_energy):
        # Scale the reward (divide by 1000) for numerical stability.
        lambda_factor = 0.9
        reward = -(simulated_energy + lambda_factor * abs(self.current_temp - self.desired_temperature)) / 1000.0
        return reward

    def _take_action(self, action):
        # Simulate HVAC energy consumption based on the chosen action.
        if action == 0:  # Off
            hvac_energy = np.random.uniform(0, 25)
        elif action == 1:  # Low
            hvac_energy = np.random.uniform(25, 100)
        elif action == 2:  # Medium
            hvac_energy = np.random.uniform(100, 300)
        elif action == 3:  # High
            hvac_energy = np.random.uniform(300, 500)
        else:
            raise ValueError("Invalid action.")
        return hvac_energy

    def step(self, action):
        simulated_energy = self._take_action(action)
        # Update the indoor temperature using a simple dynamics model.
        temp_change = (self.desired_temperature - self.current_temp) * 0.05
        self.current_temp += temp_change * (simulated_energy / 500.0)
        
        self.current_step += 1
        next_state = self._get_state()
        reward = self._get_reward(action, simulated_energy)
        done = self.current_step >= self.max_steps
        return next_state, reward, done, {"HVAC_energy": simulated_energy}

# %%
# Actor and Critic Networks for PPO

class Actor(nn.Module):
    def __init__(self, state_size, action_size):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)
        self.dropout = nn.Dropout(p=0.2)  # Dropout with 20% probability
        
    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = self.dropout(x)  # Apply dropout after the first layer
        x = torch.tanh(self.fc2(x))
        x = self.dropout(x)  # Apply dropout after the second layer
        logits = self.fc3(x)
        return logits

class Critic(nn.Module):
    def __init__(self, state_size):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 1)
        self.dropout = nn.Dropout(p=0.2)  # Dropout with 20% probability
        
    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = self.dropout(x)  # Apply dropout after the first layer
        x = torch.tanh(self.fc2(x))
        x = self.dropout(x)  # Apply dropout after the second layer
        value = self.fc3(x)
        return value

# %%
# PPO Agent (without epsilon)

class PPOAgent:
    def __init__(self, state_size, action_size, device):
        self.state_size = state_size
        self.action_size = action_size
        self.device = device

        # PPO hyperparameters.
        self.clip_epsilon = 0.2
        self.gamma = 0.99
        self.lamda = 0.95  # GAE lambda
        self.actor_lr = 1e-4
        self.critic_lr = 1e-3
        self.update_epochs = 4
        self.mini_batch_size = 64

        self.actor = Actor(state_size, action_size).to(device)
        self.critic = Critic(state_size).to(device)
        # self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=self.actor_lr)
        # self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=self.critic_lr)
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=self.actor_lr, weight_decay=1e-4)  # L2 regularization
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=self.critic_lr, weight_decay=1e-4)

    def select_action(self, state):
        state_tensor = torch.FloatTensor(state).to(self.device)
        logits = self.actor(state_tensor)
        dist = torch.distributions.Categorical(logits=logits)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        value = self.critic(state_tensor)
        return action.item(), log_prob.item(), value.item()

# %%
# Helper Function: Compute Returns and Advantages (GAE)

def compute_gae(rewards, dones, values, gamma, lamda):
    advantages = []
    gae = 0
    # Append an extra value for ease (assume terminal state has 0 value)
    values = values + [0]
    for t in reversed(range(len(rewards))):
        delta = rewards[t] + gamma * values[t+1] * (1 - dones[t]) - values[t]
        gae = delta + gamma * lamda * (1 - dones[t]) * gae
        advantages.insert(0, gae)
    returns = [adv + val for adv, val in zip(advantages, values[:-1])]
    return returns, advantages

# %%
def train_ppo(env, agent, val_env, n_episodes=1000, max_t=500, cost_factor=0.10, patience=100):
    episode_rewards = []
    episode_losses = []
    entropy_vals = []
    overall_start_time = time.time()

    best_val_reward = -float('inf')  # Track the best validation reward
    no_improvement_count = 0  # Counter for early stopping

    for episode in range(n_episodes):
        ep_start_time = time.time()
        states, actions, log_probs, rewards, dones, values = [], [], [], [], [], []
        baseline_energy_sum, rl_energy_sum, temp_deviation_sum = 0.0, 0.0, 0.0

        state = env.reset()
        total_reward = 0

        for t in range(max_t):
            baseline_energy_sum += state[-1]
            temp_deviation_sum += abs(state[0] - env.desired_temperature)

            action, log_prob, value = agent.select_action(state)
            next_state, reward, done, info = env.step(action)

            rl_energy_sum += info.get("HVAC_energy", 0.0)
            states.append(state)
            actions.append(action)
            log_probs.append(log_prob)
            rewards.append(reward)
            dones.append(1 if done else 0)
            values.append(value)

            total_reward += reward
            state = next_state
            if done:
                break

        returns, advantages = compute_gae(rewards, dones, values, agent.gamma, agent.lamda)
        states_tensor = torch.FloatTensor(np.array(states)).to(agent.device)
        actions_tensor = torch.LongTensor(actions).to(agent.device)
        old_log_probs_tensor = torch.FloatTensor(log_probs).to(agent.device)
        returns_tensor = torch.FloatTensor(returns).to(agent.device)
        advantages_tensor = torch.FloatTensor(advantages).to(agent.device)
        advantages_tensor = (advantages_tensor - advantages_tensor.mean()) / (advantages_tensor.std() + 1e-8)

        losses, episode_entropy = [], []
        dataset_size = states_tensor.size(0)
        for _ in range(agent.update_epochs):
            permutation = np.random.permutation(dataset_size)
            for i in range(0, dataset_size, agent.mini_batch_size):
                indices = permutation[i:i+agent.mini_batch_size]
                batch_states = states_tensor[indices]
                batch_actions = actions_tensor[indices]
                batch_old_log_probs = old_log_probs_tensor[indices]
                batch_returns = returns_tensor[indices]
                batch_advantages = advantages_tensor[indices]

                logits = agent.actor(batch_states)
                dist = torch.distributions.Categorical(logits=logits)
                new_log_probs = dist.log_prob(batch_actions)
                entropy = dist.entropy().mean().item()
                episode_entropy.append(entropy)

                ratio = torch.exp(new_log_probs - batch_old_log_probs)
                surr1 = ratio * batch_advantages
                surr2 = torch.clamp(ratio, 1 - agent.clip_epsilon, 1 + agent.clip_epsilon) * batch_advantages
                actor_loss = -torch.min(surr1, surr2).mean()

                values_pred = agent.critic(batch_states).squeeze()
                critic_loss = nn.MSELoss()(values_pred, batch_returns)

                loss = actor_loss + 0.5 * critic_loss
                agent.actor_optimizer.zero_grad()
                agent.critic_optimizer.zero_grad()
                loss.backward()
                agent.actor_optimizer.step()
                agent.critic_optimizer.step()
                losses.append(loss.item())

        avg_loss = np.mean(losses)
        avg_entropy = np.mean(episode_entropy)
        entropy_vals.append(avg_entropy)
        episode_rewards.append(total_reward)
        episode_losses.append(avg_loss)

        # Evaluate on validation environment
        val_results = evaluate_ppo(val_env, agent, n_episodes=10, max_t=max_t, C_energy=cost_factor)
        avg_val_reward = np.mean([result["total_reward"] for result in val_results])

        print(f"Episode {episode+1:3d} | Total Reward: {total_reward:9.2f} | Avg Loss: {avg_loss:8.4f} | "
              f"Avg Entropy: {avg_entropy:6.4f} | Validation Reward: {avg_val_reward:9.2f}")

        # Early stopping logic
        if avg_val_reward > best_val_reward:
            best_val_reward = avg_val_reward
            no_improvement_count = 0
        else:
            no_improvement_count += 1
            if no_improvement_count >= patience:
                print(f"Early stopping triggered after {episode+1} episodes.")
                break

    overall_end_time = time.time()
    total_training_time = overall_end_time - overall_start_time
    print(f"Total training time: {total_training_time:.2f} seconds")

    return episode_rewards, episode_losses, entropy_vals

# %%
# PPO Evaluation Function with Extra Metrics

def evaluate_ppo(env, agent, n_episodes=50, max_t=500, C_energy=0.10):
    results = []
    
    for episode in range(n_episodes):
        state = env.reset()
        total_reward = 0.0
        t = 0
        baseline_energy_sum = 0.0
        rl_energy_sum = 0.0
        temp_deviation_sum = 0.0
        done = False
        
        while not done and t < max_t:
            baseline_energy_sum += state[-1]
            temp_deviation_sum += abs(state[0] - env.desired_temperature)
            action, _, _ = agent.select_action(state)
            state, reward, done, info = env.step(action)
            rl_energy_sum += info.get("HVAC_energy", 0.0)
            total_reward += reward
            t += 1

            
        energy_savings = baseline_energy_sum - rl_energy_sum
        avg_temp_deviation = temp_deviation_sum / (t + 1) if t > 0 else 0.0
        cost_savings = energy_savings * C_energy
        
        print(f"Eval Episode {episode+1:3d} | Steps: {t:4d} | Total Reward: {total_reward:9.2f}")
        print(f"    Energy Savings (Wh): {energy_savings:8.2f} | Temp Deviation: {avg_temp_deviation:6.2f} | "
              f"Cost Savings ($): {cost_savings:6.2f}")
        print("--------------------------------------------------------------")
        
        results.append({
            "episode": episode+1,
            "steps": t,
            "total_reward": total_reward,
            "energy_savings": energy_savings,
            "avg_temp_deviation": avg_temp_deviation,
            "cost_savings": cost_savings
        })
        
    avg_reward = np.mean([r["total_reward"] for r in results])
    avg_energy_savings = np.mean([r["energy_savings"] for r in results])
    avg_temp_deviation = np.mean([r["avg_temp_deviation"] for r in results])
    avg_cost_savings = np.mean([r["cost_savings"] for r in results])
    print("\nFinal Average Evaluation Metrics over all evaluation episodes:")
    print(f"Avg Total Reward: {avg_reward:.2f}")
    print(f"Avg Energy Savings (Wh): {avg_energy_savings:.2f}")
    print(f"Avg Temp Deviation: {avg_temp_deviation:.2f}")
    print(f"Avg Cost Savings ($): {avg_cost_savings:.2f}")
    
    
    return results

# %%
# Evaluation Functions: Energy Consumption Comparison

def evaluate_energy_consumption(env, agent, n_episodes=1000, max_t=500):
    optimized_energy = []
    for episode in range(n_episodes):
        state = env.reset()
        total_energy = 0
        for t in range(max_t):
            action, log_prob, value = agent.select_action(state)
            state, reward, done, info = env.step(action)
            total_energy += info["HVAC_energy"]
            if done:
                break
        optimized_energy.append(total_energy)
    return optimized_energy

def evaluate_baseline_energy(env, fixed_action=2, n_episodes=100, max_t=500):
    baseline_energy = []
    for episode in range(n_episodes):
        state = env.reset()
        total_energy = 0
        for t in range(max_t):
            state, reward, done, info = env.step(fixed_action)
            total_energy += info["HVAC_energy"]
            if done:
                break
        baseline_energy.append(total_energy)
    return baseline_energy

def plot_energy_comparison(optimized_energy, baseline_energy):
    episodes = np.arange(len(optimized_energy))
    plt.figure(figsize=(8, 6))
    plt.plot(episodes, optimized_energy, label="Optimized Energy Consumption", marker='o')
    plt.plot(episodes, baseline_energy, label="Baseline Energy Consumption", marker='x')
    plt.xlabel("Evaluation Episode")
    plt.ylabel("Total HVAC Energy Consumption (Wh)")
    plt.title("Optimized vs. Baseline HVAC Energy Consumption")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Action Analysis and Visualization Functions
def analyze_action_distribution(env, agent, n_episodes=1000, max_t=500):
    action_counts = np.zeros(agent.action_size)
    for episode in range(n_episodes):
        state = env.reset()
        for t in range(max_t):
            action, log_prob, value = agent.select_action(state)
            action_counts[action] += 1
            state, reward, done, _ = env.step(action)
            if done:
                break
    action_probabilities = action_counts / np.sum(action_counts)
    
    # Plot histogram/bar chart
    actions = np.arange(agent.action_size)
    plt.figure(figsize=(8, 4))
    plt.bar(actions, action_counts, tick_label=["Off", "Low", "Medium", "High"], color='skyblue')
    plt.xlabel("Actions")
    plt.ylabel("Frequency")
    plt.title("Action Selection Frequency over {} Episodes".format(n_episodes))
    plt.show()
    
    return action_counts, action_probabilities

def visualize_policy_for_state(env, agent, sample_state=None):
    if sample_state is None:
        sample_state = env.reset()
    
    state_tensor = torch.FloatTensor(sample_state).to(agent.device)
    logits = agent.actor(state_tensor)
    probabilities = torch.softmax(logits, dim=-1).detach().cpu().numpy()
    
    actions = np.arange(agent.action_size)
    plt.figure(figsize=(6, 4))
    plt.bar(actions, probabilities, tick_label=["Off", "Low", "Medium", "High"], color='magenta')
    plt.xlabel("Actions")
    plt.ylabel("Probability")
    plt.title("Action Probabilities for a Sample State")
    plt.ylim([0, 1])
    plt.show()
    
    print("Sample State:", sample_state)
    print("Action probabilities:", probabilities)

# %%
# Plotting Functions 
def plot_training_results(rewards, losses, entropy_vals):
    episodes = np.arange(len(rewards))
    
    # Plot Total Reward per Episode
    plt.figure(figsize=(8, 6))
    plt.plot(episodes, rewards, label="Total Reward")
    plt.title("Total Reward per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # Plot Average Loss per Episode
    plt.figure(figsize=(8, 6))
    plt.plot(episodes, losses, label="Loss", color="red")
    plt.title("Average Loss per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # Plot Entropy Evolution
    plt.figure(figsize=(8, 6))
    plt.plot(episodes, entropy_vals, label="Entropy", color="green")
    plt.title("Entropy Evolution")
    plt.xlabel("Episode")
    plt.ylabel("Entropy")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Function to save the PPO model as .h5 format
def save_model_as_h5(agent, filepath):
    # Save the actor and critic state dictionaries
    actor_state_dict = agent.actor.state_dict()
    critic_state_dict = agent.critic.state_dict()
    
    # Create an HDF5 file
    with h5py.File(filepath, 'w') as h5file:
        # Save actor state dictionary
        actor_group = h5file.create_group('actor')
        for key, value in actor_state_dict.items():
            actor_group.create_dataset(key, data=value.cpu().numpy())
        
        # Save critic state dictionary
        critic_group = h5file.create_group('critic')
        for key, value in critic_state_dict.items():
            critic_group.create_dataset(key, data=value.cpu().numpy())
    
    print(f"Model saved to {filepath}")

# %%
# K-Fold Cross-Validation Function

def kfold_cross_validation(df, k=5, n_episodes=1000, max_t=500, cost_factor=0.10, patience=10):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    fold_results = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(df)):
        print(f"\n=== Fold {fold + 1}/{k} ===")

        train_data = df.iloc[train_idx]
        val_data = df.iloc[val_idx]

        env_train = HVACEnvironment(train_data, desired_temperature=22)
        env_val = HVACEnvironment(val_data, desired_temperature=22)

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        state_size = env_train.observation_space_shape
        action_size = env_train.action_space_n
        ppo_agent = PPOAgent(state_size, action_size, device)

        print("\nTraining PPO with Early Stopping...")
        train_rewards, train_losses, entropy_vals = train_ppo(
            env_train, ppo_agent, env_val, n_episodes=n_episodes, max_t=max_t, cost_factor=cost_factor, patience=patience
        )

        val_results = evaluate_ppo(env_val, ppo_agent, n_episodes=100, max_t=max_t, C_energy=cost_factor)
        val_rewards = [result["total_reward"] for result in val_results]
        avg_val_reward = np.mean(val_rewards)
        print(f"Fold {fold + 1} Average Validation Reward: {avg_val_reward:.2f}")

        fold_results.append({
            "fold": fold + 1,
            "train_rewards": train_rewards,
            "val_rewards": val_rewards,
            "avg_val_reward": avg_val_reward
        })

    return fold_results

# %%
# Main Execution

if __name__ == "__main__":
    # Load and Preprocess the Data
    df = pd.read_csv("data/raw_data.csv")
    df = preprocess_data(df)
    
    # Perform K-Fold Cross-Validation 
    k = 5  # Number of folds
    print("\nPerforming K-Fold Cross-Validation...")
    fold_results = kfold_cross_validation(df, k=k, n_episodes=1000, max_t=500, cost_factor=0.10, patience=10)

    avg_rewards = [result["avg_val_reward"] for result in fold_results]
    print(f"\nOverall Average Validation Reward across {k} folds: {np.mean(avg_rewards):.2f}")
    
    # Data Split: 70% Train, 15% Test, 15% Validation 
    print("\nSplitting data into train, test, and validation sets...")
    train_data, temp_data = train_test_split(df, test_size=0.30, random_state=42)
    test_data, val_data = train_test_split(temp_data, test_size=0.50, random_state=42)
    print(f"Train samples: {len(train_data)}")
    print(f"Test samples: {len(test_data)}")
    print(f"Validation samples: {len(val_data)}")
    
    # Create Environments for each Data Split
    env_train = HVACEnvironment(train_data, desired_temperature=22)
    env_test  = HVACEnvironment(test_data, desired_temperature=22)
    env_val   = HVACEnvironment(val_data, desired_temperature=22)
    
    # Initialize the PPO Agent 
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    state_size = env_train.observation_space_shape
    action_size = env_train.action_space_n
    ppo_agent = PPOAgent(state_size, action_size, device)
    
    # Train the PPO Agent on the Training Split
    print("\nTraining PPO on the full training split...")
    train_rewards, train_losses, entropy_vals = train_ppo(
        env_train, ppo_agent, env_val, n_episodes=10000, max_t=500, cost_factor=0.10, patience=100)
    
    # Save the trained model
    save_model_as_h5(ppo_agent, "/Users/amalshar/Desktop/USD/Spring 2025/Applied Reinforecement Learning/RL Project/exp1_ppo_model.h5")

    # Save training results to a JSON file
    results = {
        "rewards": train_rewards,
        "losses": train_losses,
        "entropy": entropy_vals
    }
    with open("/Users/amalshar/Desktop/USD/Spring 2025/Applied Reinforecement Learning/RL Project/exp1_results.json", "w") as f:
        json.dump(results, f)
    print("Training results saved to exp1_results.json")
    
    # Evaluate the trained PPO model
    print("\nEvaluating PPO on the test split...")
    test_results = evaluate_ppo(env_test, ppo_agent, n_episodes=1000, max_t=500, C_energy=0.10)

    print("\nEvaluating PPO on the validation split...")
    val_results = evaluate_ppo(env_val, ppo_agent, n_episodes=1000, max_t=500, C_energy=0.10)

    # Extract total rewards from test_results
    test_rewards = [result["total_reward"] for result in test_results]

    # Assuming success_rates is a list of success rates per episode
    plot_training_results(train_rewards, train_losses, entropy_vals)
    
    optimized_energy = evaluate_energy_consumption(env_test, ppo_agent, n_episodes=100, max_t=500)
    baseline_energy = evaluate_baseline_energy(env_test, fixed_action=2, n_episodes=100, max_t=500)
    plot_energy_comparison(optimized_energy, baseline_energy)
    
    action_counts, action_probs = analyze_action_distribution(env_test, ppo_agent, n_episodes=100, max_t=500)
    print("Action counts:", action_counts)
    print("Action probabilities:", action_probs)
    visualize_policy_for_state(env_test, ppo_agent)
# Out:
# Performing K-Fold Cross-Validation...
#
# === Fold 1/5 ===
#
# Training PPO with Early Stopping...
# Eval Episode   1 | Steps:  500 | Total Reward:    -71.89
#     Energy Savings (Wh): -29012.88 | Temp Deviation:   0.73 | Cost Savings ($): -2901.29
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -66.65
#     Energy Savings (Wh): -23773.37 | Temp Deviation:   0.73 | Cost Savings ($): -2377.34
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -70.38
#     Energy Savings (Wh): -27514.20 | Temp Deviation:   0.70 | Cost Savings ($): -2751.42
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -71.70
#     Energy Savings (Wh): -28864.23 | Temp Deviation:   0.63 | Cost Savings ($): -2886.42
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -77.67
#     Energy Savings (Wh): -34845.43 | Temp Deviation:   0.63 | Cost Savings ($): -3484.54
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -75.43
#     Energy Savings (Wh): -32603.57 | Temp Deviation:   0.62 | Cost Savings ($): -3260.36
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -70.36
#     Energy Savings (Wh): -27508.69 | Temp Deviation:   0.68 | Cost Savings ($): -2750.87
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -73.51
#     Energy Savings (Wh): -30667.25 | Temp Deviation:   0.66 | Cost Savings ($): -3066.73
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -69.15
#     Energy Savings (Wh): -26328.98 | Temp Deviation:   0.60 | Cost Savings ($): -2632.90
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -71.08
#     Energy Savings (Wh): -28252.49 | Temp Deviation:   0.62 | Cost Savings ($): -2825.25
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -71.78
# Avg Energy Savings (Wh): -28937.11
# Avg Temp Deviation: 0.66
# Avg Cost Savings ($): -2893.71
# Episode   1 | Total Reward:    -81.40 | Avg Loss:   0.9638 | Avg Entropy: 1.3383 | Validation Reward:    -71.78
# Eval Episode   1 | Steps:  500 | Total Reward:    -70.46
#     Energy Savings (Wh): -27628.29 | Temp Deviation:   0.63 | Cost Savings ($): -2762.83
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -67.61
#     Energy Savings (Wh): -24737.12 | Temp Deviation:   0.73 | Cost Savings ($): -2473.71
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -62.95
#     Energy Savings (Wh): -20085.74 | Temp Deviation:   0.71 | Cost Savings ($): -2008.57
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -61.99
#     Energy Savings (Wh): -19077.27 | Temp Deviation:   0.82 | Cost Savings ($): -1907.73
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -58.39
#     Energy Savings (Wh): -15518.85 | Temp Deviation:   0.73 | Cost Savings ($): -1551.89
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -62.82
#     Energy Savings (Wh): -19882.28 | Temp Deviation:   0.88 | Cost Savings ($): -1988.23
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -66.14
#     Energy Savings (Wh): -23195.89 | Temp Deviation:   0.88 | Cost Savings ($): -2319.59
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -70.01
#     Energy Savings (Wh): -27164.84 | Temp Deviation:   0.67 | Cost Savings ($): -2716.48
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -63.34
#     Energy Savings (Wh): -20482.49 | Temp Deviation:   0.68 | Cost Savings ($): -2048.25
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -59.17
#     Energy Savings (Wh): -16279.63 | Temp Deviation:   0.76 | Cost Savings ($): -1627.96
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -64.29
# Avg Energy Savings (Wh): -21405.24
# Avg Temp Deviation: 0.75
# Avg Cost Savings ($): -2140.52
# Episode   2 | Total Reward:    -69.26 | Avg Loss:   0.7527 | Avg Entropy: 1.3116 | Validation Reward:    -64.29
# Eval Episode   1 | Steps:  500 | Total Reward:    -58.69
#     Energy Savings (Wh): -15780.15 | Temp Deviation:   0.80 | Cost Savings ($): -1578.02
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -58.75
#     Energy Savings (Wh): -15833.06 | Temp Deviation:   0.81 | Cost Savings ($): -1583.31
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -52.33
#     Energy Savings (Wh): -9369.08 | Temp Deviation:   0.91 | Cost Savings ($): -936.91
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -56.66
#     Energy Savings (Wh): -13714.16 | Temp Deviation:   0.89 | Cost Savings ($): -1371.42
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -51.45
#     Energy Savings (Wh): -8481.51 | Temp Deviation:   0.94 | Cost Savings ($): -848.15
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -51.78
#     Energy Savings (Wh): -8844.33 | Temp Deviation:   0.88 | Cost Savings ($): -884.43
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -59.63
#     Energy Savings (Wh): -16695.61 | Temp Deviation:   0.86 | Cost Savings ($): -1669.56
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -56.01
#     Energy Savings (Wh): -13124.11 | Temp Deviation:   0.74 | Cost Savings ($): -1312.41
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -57.29
#     Energy Savings (Wh): -14375.46 | Temp Deviation:   0.81 | Cost Savings ($): -1437.55
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -61.88
#     Energy Savings (Wh): -18984.78 | Temp Deviation:   0.78 | Cost Savings ($): -1898.48
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -56.45
# Avg Energy Savings (Wh): -13520.22
# Avg Temp Deviation: 0.84
# Avg Cost Savings ($): -1352.02
# Episode   3 | Total Reward:    -64.96 | Avg Loss:   0.7303 | Avg Entropy: 1.2711 | Validation Reward:    -56.45
# Eval Episode   1 | Steps:  500 | Total Reward:    -51.51
#     Energy Savings (Wh): -8533.89 | Temp Deviation:   0.94 | Cost Savings ($): -853.39
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -48.54
#     Energy Savings (Wh): -5508.60 | Temp Deviation:   1.08 | Cost Savings ($): -550.86
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -50.95
#     Energy Savings (Wh): -7948.26 | Temp Deviation:   1.01 | Cost Savings ($): -794.83
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -51.37
#     Energy Savings (Wh): -8375.61 | Temp Deviation:   0.99 | Cost Savings ($): -837.56
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -49.43
#     Energy Savings (Wh): -6478.76 | Temp Deviation:   0.91 | Cost Savings ($): -647.88
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -50.53
#     Energy Savings (Wh): -7555.08 | Temp Deviation:   0.95 | Cost Savings ($): -755.51
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -46.99
#     Energy Savings (Wh): -4032.69 | Temp Deviation:   0.92 | Cost Savings ($): -403.27
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -44.65
#     Energy Savings (Wh): -1671.67 | Temp Deviation:   0.96 | Cost Savings ($): -167.17
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -48.36
#     Energy Savings (Wh): -5382.24 | Temp Deviation:   0.95 | Cost Savings ($): -538.22
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -49.93
#     Energy Savings (Wh): -6947.61 | Temp Deviation:   0.96 | Cost Savings ($): -694.76
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -49.23
# Avg Energy Savings (Wh): -6243.44
# Avg Temp Deviation: 0.97
# Avg Cost Savings ($): -624.34
# Episode   4 | Total Reward:    -59.43 | Avg Loss:   0.8391 | Avg Entropy: 1.2249 | Validation Reward:    -49.23
# Eval Episode   1 | Steps:  500 | Total Reward:    -46.75
#     Energy Savings (Wh): -3664.58 | Temp Deviation:   1.20 | Cost Savings ($): -366.46
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -47.91
#     Energy Savings (Wh): -4984.23 | Temp Deviation:   0.85 | Cost Savings ($): -498.42
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -46.42
#     Energy Savings (Wh): -3398.27 | Temp Deviation:   1.06 | Cost Savings ($): -339.83
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -50.95
#     Energy Savings (Wh): -7934.26 | Temp Deviation:   1.05 | Cost Savings ($): -793.43
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -46.33
#     Energy Savings (Wh): -3356.57 | Temp Deviation:   0.96 | Cost Savings ($): -335.66
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -51.65
#     Energy Savings (Wh): -8628.85 | Temp Deviation:   1.05 | Cost Savings ($): -862.88
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -48.93
#     Energy Savings (Wh): -6022.99 | Temp Deviation:   0.80 | Cost Savings ($): -602.30
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -50.30
#     Energy Savings (Wh): -7321.79 | Temp Deviation:   0.96 | Cost Savings ($): -732.18
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -54.61
#     Energy Savings (Wh): -11657.43 | Temp Deviation:   0.89 | Cost Savings ($): -1165.74
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -48.01
#     Energy Savings (Wh): -4959.14 | Temp Deviation:   1.13 | Cost Savings ($): -495.91
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -49.19
# Avg Energy Savings (Wh): -6192.81
# Avg Temp Deviation: 0.99
# Avg Cost Savings ($): -619.28
# Episode   5 | Total Reward:    -42.93 | Avg Loss:   0.5342 | Avg Entropy: 1.1798 | Validation Reward:    -49.19
# Eval Episode   1 | Steps:  500 | Total Reward:    -43.43
#     Energy Savings (Wh):  -331.67 | Temp Deviation:   1.23 | Cost Savings ($): -33.17
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -44.78
#     Energy Savings (Wh): -1703.39 | Temp Deviation:   1.18 | Cost Savings ($): -170.34
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -44.31
#     Energy Savings (Wh): -1277.80 | Temp Deviation:   1.09 | Cost Savings ($): -127.78
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -43.46
#     Energy Savings (Wh):  -454.46 | Temp Deviation:   1.02 | Cost Savings ($): -45.45
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -40.04
#     Energy Savings (Wh):  3067.01 | Temp Deviation:   1.24 | Cost Savings ($): 306.70
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -41.43
#     Energy Savings (Wh):  1549.58 | Temp Deviation:   0.97 | Cost Savings ($): 154.96
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -40.98
#     Energy Savings (Wh):  2132.92 | Temp Deviation:   1.26 | Cost Savings ($): 213.29
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -39.68
#     Energy Savings (Wh):  3416.00 | Temp Deviation:   1.23 | Cost Savings ($): 341.60
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -41.60
#     Energy Savings (Wh):  1495.87 | Temp Deviation:   1.21 | Cost Savings ($): 149.59
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -43.14
#     Energy Savings (Wh):   -47.90 | Temp Deviation:   1.20 | Cost Savings ($):  -4.79
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -42.29
# Avg Energy Savings (Wh): 784.62
# Avg Temp Deviation: 1.16
# Avg Cost Savings ($): 78.46
# Episode   6 | Total Reward:    -48.38 | Avg Loss:   0.6835 | Avg Entropy: 1.1305 | Validation Reward:    -42.29
# Eval Episode   1 | Steps:  500 | Total Reward:    -38.09
#     Energy Savings (Wh):  4980.42 | Temp Deviation:   1.15 | Cost Savings ($): 498.04
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -35.58
#     Energy Savings (Wh):  7601.70 | Temp Deviation:   1.40 | Cost Savings ($): 760.17
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -39.20
#     Energy Savings (Wh):  3835.29 | Temp Deviation:   1.08 | Cost Savings ($): 383.53
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -40.95
#     Energy Savings (Wh):  2160.77 | Temp Deviation:   1.26 | Cost Savings ($): 216.08
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -37.34
#     Energy Savings (Wh):  5659.13 | Temp Deviation:   1.01 | Cost Savings ($): 565.91
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -41.50
#     Energy Savings (Wh):  1579.33 | Temp Deviation:   1.18 | Cost Savings ($): 157.93
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -37.00
#     Energy Savings (Wh):  6304.82 | Temp Deviation:   1.68 | Cost Savings ($): 630.48
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -38.80
#     Energy Savings (Wh):  4258.84 | Temp Deviation:   1.14 | Cost Savings ($): 425.88
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -40.07
#     Energy Savings (Wh):  3001.46 | Temp Deviation:   1.17 | Cost Savings ($): 300.15
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -47.91
#     Energy Savings (Wh): -4902.41 | Temp Deviation:   1.02 | Cost Savings ($): -490.24
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -39.64
# Avg Energy Savings (Wh): 3447.94
# Avg Temp Deviation: 1.21
# Avg Cost Savings ($): 344.79
# Episode   7 | Total Reward:    -45.93 | Avg Loss:   0.6223 | Avg Entropy: 1.0542 | Validation Reward:    -39.64
# Eval Episode   1 | Steps:  500 | Total Reward:    -29.12
#     Energy Savings (Wh): 14126.47 | Temp Deviation:   1.55 | Cost Savings ($): 1412.65
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -32.82
#     Energy Savings (Wh): 10455.11 | Temp Deviation:   1.61 | Cost Savings ($): 1045.51
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -34.04
#     Energy Savings (Wh):  9139.38 | Temp Deviation:   1.40 | Cost Savings ($): 913.94
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -33.88
#     Energy Savings (Wh):  9301.62 | Temp Deviation:   1.42 | Cost Savings ($): 930.16
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -37.86
#     Energy Savings (Wh):  5186.64 | Temp Deviation:   1.12 | Cost Savings ($): 518.66
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -39.20
#     Energy Savings (Wh):  3885.39 | Temp Deviation:   1.19 | Cost Savings ($): 388.54
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -37.60
#     Energy Savings (Wh):  5547.57 | Temp Deviation:   1.34 | Cost Savings ($): 554.76
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -39.74
#     Energy Savings (Wh):  3362.94 | Temp Deviation:   1.23 | Cost Savings ($): 336.29
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -35.30
#     Energy Savings (Wh):  7948.68 | Temp Deviation:   1.55 | Cost Savings ($): 794.87
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -32.43
#     Energy Savings (Wh): 10813.87 | Temp Deviation:   1.56 | Cost Savings ($): 1081.39
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -35.20
# Avg Energy Savings (Wh): 7976.77
# Avg Temp Deviation: 1.40
# Avg Cost Savings ($): 797.68
# Episode   8 | Total Reward:    -40.00 | Avg Loss:   0.6131 | Avg Entropy: 0.9933 | Validation Reward:    -35.20
# Eval Episode   1 | Steps:  500 | Total Reward:    -30.54
#     Energy Savings (Wh): 12770.93 | Temp Deviation:   1.69 | Cost Savings ($): 1277.09
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -32.37
#     Energy Savings (Wh): 10817.06 | Temp Deviation:   1.42 | Cost Savings ($): 1081.71
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -33.29
#     Energy Savings (Wh):  9915.78 | Temp Deviation:   1.46 | Cost Savings ($): 991.58
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -34.09
#     Energy Savings (Wh):  9061.38 | Temp Deviation:   1.35 | Cost Savings ($): 906.14
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -33.39
#     Energy Savings (Wh):  9934.50 | Temp Deviation:   1.72 | Cost Savings ($): 993.45
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -30.19
#     Energy Savings (Wh): 13149.81 | Temp Deviation:   1.76 | Cost Savings ($): 1314.98
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -35.67
#     Energy Savings (Wh):  7548.25 | Temp Deviation:   1.50 | Cost Savings ($): 754.82
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -35.33
#     Energy Savings (Wh):  7770.37 | Temp Deviation:   1.23 | Cost Savings ($): 777.04
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -33.51
#     Energy Savings (Wh):  9692.18 | Temp Deviation:   1.45 | Cost Savings ($): 969.22
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -37.48
#     Energy Savings (Wh):  5658.55 | Temp Deviation:   1.32 | Cost Savings ($): 565.86
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -33.59
# Avg Energy Savings (Wh): 9631.88
# Avg Temp Deviation: 1.49
# Avg Cost Savings ($): 963.19
# Episode   9 | Total Reward:    -31.45 | Avg Loss:   0.5137 | Avg Entropy: 0.9512 | Validation Reward:    -33.59
# Eval Episode   1 | Steps:  500 | Total Reward:    -31.67
#     Energy Savings (Wh): 11467.48 | Temp Deviation:   1.31 | Cost Savings ($): 1146.75
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -25.39
#     Energy Savings (Wh): 17953.93 | Temp Deviation:   1.76 | Cost Savings ($): 1795.39
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -26.17
#     Energy Savings (Wh): 17208.85 | Temp Deviation:   1.84 | Cost Savings ($): 1720.89
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -31.74
#     Energy Savings (Wh): 11516.66 | Temp Deviation:   1.57 | Cost Savings ($): 1151.67
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -28.59
#     Energy Savings (Wh): 14655.90 | Temp Deviation:   1.56 | Cost Savings ($): 1465.59
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -27.94
#     Energy Savings (Wh): 15309.09 | Temp Deviation:   1.57 | Cost Savings ($): 1530.91
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -26.68
#     Energy Savings (Wh): 16745.09 | Temp Deviation:   1.96 | Cost Savings ($): 1674.51
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -28.46
#     Energy Savings (Wh): 14852.13 | Temp Deviation:   1.70 | Cost Savings ($): 1485.21
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -33.24
#     Energy Savings (Wh): 10026.93 | Temp Deviation:   1.59 | Cost Savings ($): 1002.69
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -27.75
#     Energy Savings (Wh): 15571.29 | Temp Deviation:   1.72 | Cost Savings ($): 1557.13
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -28.76
# Avg Energy Savings (Wh): 14530.73
# Avg Temp Deviation: 1.66
# Avg Cost Savings ($): 1453.07
# Episode  10 | Total Reward:    -33.89 | Avg Loss:   0.5467 | Avg Entropy: 0.8806 | Validation Reward:    -28.76
# Eval Episode   1 | Steps:  500 | Total Reward:    -27.93
#     Energy Savings (Wh): 15347.02 | Temp Deviation:   1.62 | Cost Savings ($): 1534.70
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -25.88
#     Energy Savings (Wh): 17531.47 | Temp Deviation:   1.92 | Cost Savings ($): 1753.15
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -25.03
#     Energy Savings (Wh): 18283.16 | Temp Deviation:   1.69 | Cost Savings ($): 1828.32
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -28.38
#     Energy Savings (Wh): 14822.36 | Temp Deviation:   1.45 | Cost Savings ($): 1482.24
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -26.43
#     Energy Savings (Wh): 16878.29 | Temp Deviation:   1.69 | Cost Savings ($): 1687.83
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -25.68
#     Energy Savings (Wh): 17606.46 | Temp Deviation:   1.64 | Cost Savings ($): 1760.65
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -27.29
#     Energy Savings (Wh): 16090.14 | Temp Deviation:   1.85 | Cost Savings ($): 1609.01
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -25.20
#     Energy Savings (Wh): 18212.89 | Temp Deviation:   1.92 | Cost Savings ($): 1821.29
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -24.49
#     Energy Savings (Wh): 18890.34 | Temp Deviation:   1.85 | Cost Savings ($): 1889.03
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -29.17
#     Energy Savings (Wh): 14151.65 | Temp Deviation:   1.73 | Cost Savings ($): 1415.16
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -26.55
# Avg Energy Savings (Wh): 16781.38
# Avg Temp Deviation: 1.74
# Avg Cost Savings ($): 1678.14
# Episode  11 | Total Reward:    -30.32 | Avg Loss:   0.4383 | Avg Entropy: 0.8183 | Validation Reward:    -26.55
# Eval Episode   1 | Steps:  500 | Total Reward:    -23.79
#     Energy Savings (Wh): 19635.66 | Temp Deviation:   1.96 | Cost Savings ($): 1963.57
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -26.92
#     Energy Savings (Wh): 16433.99 | Temp Deviation:   1.79 | Cost Savings ($): 1643.40
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -21.47
#     Energy Savings (Wh): 22015.64 | Temp Deviation:   2.09 | Cost Savings ($): 2201.56
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -26.60
#     Energy Savings (Wh): 16691.81 | Temp Deviation:   1.65 | Cost Savings ($): 1669.18
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -26.50
#     Energy Savings (Wh): 16852.98 | Temp Deviation:   1.80 | Cost Savings ($): 1685.30
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -20.39
#     Energy Savings (Wh): 23154.21 | Temp Deviation:   2.22 | Cost Savings ($): 2315.42
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -21.83
#     Energy Savings (Wh): 21606.69 | Temp Deviation:   1.97 | Cost Savings ($): 2160.67
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -25.51
#     Energy Savings (Wh): 17859.25 | Temp Deviation:   1.82 | Cost Savings ($): 1785.92
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -23.95
#     Energy Savings (Wh): 19538.39 | Temp Deviation:   2.10 | Cost Savings ($): 1953.84
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -21.63
#     Energy Savings (Wh): 21856.57 | Temp Deviation:   2.09 | Cost Savings ($): 2185.66
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -23.86
# Avg Energy Savings (Wh): 19564.52
# Avg Temp Deviation: 1.95
# Avg Cost Savings ($): 1956.45
# Episode  12 | Total Reward:    -21.87 | Avg Loss:   0.3994 | Avg Entropy: 0.7616 | Validation Reward:    -23.86
# Eval Episode   1 | Steps:  500 | Total Reward:    -22.85
#     Energy Savings (Wh): 20677.92 | Temp Deviation:   2.17 | Cost Savings ($): 2067.79
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -24.46
#     Energy Savings (Wh): 18867.82 | Temp Deviation:   1.73 | Cost Savings ($): 1886.78
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -19.19
#     Energy Savings (Wh): 24399.94 | Temp Deviation:   2.32 | Cost Savings ($): 2439.99
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -22.44
#     Energy Savings (Wh): 21031.88 | Temp Deviation:   2.06 | Cost Savings ($): 2103.19
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -23.98
#     Energy Savings (Wh): 19535.96 | Temp Deviation:   2.15 | Cost Savings ($): 1953.60
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -19.54
#     Energy Savings (Wh): 23955.83 | Temp Deviation:   2.10 | Cost Savings ($): 2395.58
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -21.16
#     Energy Savings (Wh): 22291.97 | Temp Deviation:   2.00 | Cost Savings ($): 2229.20
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -19.53
#     Energy Savings (Wh): 23929.53 | Temp Deviation:   2.02 | Cost Savings ($): 2392.95
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -20.01
#     Energy Savings (Wh): 23594.89 | Temp Deviation:   2.36 | Cost Savings ($): 2359.49
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -25.18
#     Energy Savings (Wh): 18232.09 | Temp Deviation:   1.93 | Cost Savings ($): 1823.21
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -21.83
# Avg Energy Savings (Wh): 21651.78
# Avg Temp Deviation: 2.08
# Avg Cost Savings ($): 2165.18
# Episode  13 | Total Reward:    -24.78 | Avg Loss:   0.3987 | Avg Entropy: 0.6921 | Validation Reward:    -21.83
# Eval Episode   1 | Steps:  500 | Total Reward:    -19.38
#     Energy Savings (Wh): 24203.58 | Temp Deviation:   2.30 | Cost Savings ($): 2420.36
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -20.72
#     Energy Savings (Wh): 22753.22 | Temp Deviation:   2.05 | Cost Savings ($): 2275.32
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -20.54
#     Energy Savings (Wh): 23020.15 | Temp Deviation:   2.25 | Cost Savings ($): 2302.01
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -19.89
#     Energy Savings (Wh): 23671.17 | Temp Deviation:   2.25 | Cost Savings ($): 2367.12
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -19.99
#     Energy Savings (Wh): 23480.74 | Temp Deviation:   2.06 | Cost Savings ($): 2348.07
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -19.25
#     Energy Savings (Wh): 24295.93 | Temp Deviation:   2.23 | Cost Savings ($): 2429.59
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -18.85
#     Energy Savings (Wh): 24684.31 | Temp Deviation:   2.18 | Cost Savings ($): 2468.43
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -18.56
#     Energy Savings (Wh): 25040.41 | Temp Deviation:   2.33 | Cost Savings ($): 2504.04
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -16.91
#     Energy Savings (Wh): 26788.78 | Temp Deviation:   2.55 | Cost Savings ($): 2678.88
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -21.36
#     Energy Savings (Wh): 22104.84 | Temp Deviation:   2.03 | Cost Savings ($): 2210.48
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -19.54
# Avg Energy Savings (Wh): 24004.31
# Avg Temp Deviation: 2.22
# Avg Cost Savings ($): 2400.43
# Episode  14 | Total Reward:    -22.32 | Avg Loss:   0.3240 | Avg Entropy: 0.6037 | Validation Reward:    -19.54
# Eval Episode   1 | Steps:  500 | Total Reward:    -15.46
#     Energy Savings (Wh): 28278.27 | Temp Deviation:   2.64 | Cost Savings ($): 2827.83
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -17.17
#     Energy Savings (Wh): 26480.84 | Temp Deviation:   2.45 | Cost Savings ($): 2648.08
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -18.63
#     Energy Savings (Wh): 24903.05 | Temp Deviation:   2.18 | Cost Savings ($): 2490.30
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -18.81
#     Energy Savings (Wh): 24853.98 | Temp Deviation:   2.48 | Cost Savings ($): 2485.40
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -15.25
#     Energy Savings (Wh): 28507.40 | Temp Deviation:   2.69 | Cost Savings ($): 2850.74
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -14.26
#     Energy Savings (Wh): 29533.53 | Temp Deviation:   2.77 | Cost Savings ($): 2953.35
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -16.57
#     Energy Savings (Wh): 27074.41 | Temp Deviation:   2.43 | Cost Savings ($): 2707.44
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -16.17
#     Energy Savings (Wh): 27546.95 | Temp Deviation:   2.59 | Cost Savings ($): 2754.69
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -16.93
#     Energy Savings (Wh): 26715.14 | Temp Deviation:   2.43 | Cost Savings ($): 2671.51
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -15.33
#     Energy Savings (Wh): 28388.88 | Temp Deviation:   2.60 | Cost Savings ($): 2838.89
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -16.46
# Avg Energy Savings (Wh): 27228.24
# Avg Temp Deviation: 2.52
# Avg Cost Savings ($): 2722.82
# Episode  15 | Total Reward:    -18.55 | Avg Loss:   0.2885 | Avg Entropy: 0.5233 | Validation Reward:    -16.46
# Eval Episode   1 | Steps:  500 | Total Reward:    -18.37
#     Energy Savings (Wh): 25254.06 | Temp Deviation:   2.40 | Cost Savings ($): 2525.41
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -18.55
#     Energy Savings (Wh): 24938.23 | Temp Deviation:   2.09 | Cost Savings ($): 2493.82
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -13.50
#     Energy Savings (Wh): 30256.70 | Temp Deviation:   2.67 | Cost Savings ($): 3025.67
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -12.89
#     Energy Savings (Wh): 31010.64 | Temp Deviation:   3.00 | Cost Savings ($): 3101.06
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -16.32
#     Energy Savings (Wh): 27266.53 | Temp Deviation:   2.31 | Cost Savings ($): 2726.65
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -16.17
#     Energy Savings (Wh): 27513.76 | Temp Deviation:   2.52 | Cost Savings ($): 2751.38
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -17.47
#     Energy Savings (Wh): 26123.13 | Temp Deviation:   2.32 | Cost Savings ($): 2612.31
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -16.46
#     Energy Savings (Wh): 27194.66 | Temp Deviation:   2.47 | Cost Savings ($): 2719.47
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -17.27
#     Energy Savings (Wh): 26378.19 | Temp Deviation:   2.45 | Cost Savings ($): 2637.82
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -15.71
#     Energy Savings (Wh): 28003.77 | Temp Deviation:   2.59 | Cost Savings ($): 2800.38
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -16.27
# Avg Energy Savings (Wh): 27393.97
# Avg Temp Deviation: 2.48
# Avg Cost Savings ($): 2739.40
# Episode  16 | Total Reward:    -16.81 | Avg Loss:   0.2280 | Avg Entropy: 0.4635 | Validation Reward:    -16.27
# Eval Episode   1 | Steps:  500 | Total Reward:    -14.94
#     Energy Savings (Wh): 28850.06 | Temp Deviation:   2.76 | Cost Savings ($): 2885.01
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -13.57
#     Energy Savings (Wh): 30142.24 | Temp Deviation:   2.59 | Cost Savings ($): 3014.22
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -14.76
#     Energy Savings (Wh): 28898.34 | Temp Deviation:   2.46 | Cost Savings ($): 2889.83
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -15.60
#     Energy Savings (Wh): 28018.39 | Temp Deviation:   2.37 | Cost Savings ($): 2801.84
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -15.65
#     Energy Savings (Wh): 28103.81 | Temp Deviation:   2.68 | Cost Savings ($): 2810.38
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -12.36
#     Energy Savings (Wh): 31434.73 | Temp Deviation:   2.77 | Cost Savings ($): 3143.47
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -15.11
#     Energy Savings (Wh): 28715.86 | Temp Deviation:   2.83 | Cost Savings ($): 2871.59
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -13.83
#     Energy Savings (Wh): 29951.69 | Temp Deviation:   2.74 | Cost Savings ($): 2995.17
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -15.72
#     Energy Savings (Wh): 28086.53 | Temp Deviation:   2.80 | Cost Savings ($): 2808.65
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -13.45
#     Energy Savings (Wh): 30411.98 | Temp Deviation:   2.91 | Cost Savings ($): 3041.20
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -14.50
# Avg Energy Savings (Wh): 29261.36
# Avg Temp Deviation: 2.69
# Avg Cost Savings ($): 2926.14
# Episode  17 | Total Reward:    -15.37 | Avg Loss:   0.2037 | Avg Entropy: 0.4255 | Validation Reward:    -14.50
# Eval Episode   1 | Steps:  500 | Total Reward:    -14.48
#     Energy Savings (Wh): 29286.85 | Temp Deviation:   2.72 | Cost Savings ($): 2928.68
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -14.87
#     Energy Savings (Wh): 28931.32 | Temp Deviation:   2.79 | Cost Savings ($): 2893.13
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -15.71
#     Energy Savings (Wh): 27976.40 | Temp Deviation:   2.52 | Cost Savings ($): 2797.64
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -12.45
#     Energy Savings (Wh): 31440.23 | Temp Deviation:   2.99 | Cost Savings ($): 3144.02
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -15.17
#     Energy Savings (Wh): 28585.69 | Temp Deviation:   2.67 | Cost Savings ($): 2858.57
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -14.20
#     Energy Savings (Wh): 29486.59 | Temp Deviation:   2.53 | Cost Savings ($): 2948.66
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -11.87
#     Energy Savings (Wh): 31982.17 | Temp Deviation:   2.90 | Cost Savings ($): 3198.22
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -14.48
#     Energy Savings (Wh): 29288.86 | Temp Deviation:   2.72 | Cost Savings ($): 2928.89
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -15.29
#     Energy Savings (Wh): 28346.44 | Temp Deviation:   2.43 | Cost Savings ($): 2834.64
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -16.42
#     Energy Savings (Wh): 27343.41 | Temp Deviation:   2.71 | Cost Savings ($): 2734.34
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -14.50
# Avg Energy Savings (Wh): 29266.80
# Avg Temp Deviation: 2.70
# Avg Cost Savings ($): 2926.68
# Episode  18 | Total Reward:    -11.71 | Avg Loss:   0.1583 | Avg Entropy: 0.3943 | Validation Reward:    -14.50
# Eval Episode   1 | Steps:  500 | Total Reward:    -15.40
#     Energy Savings (Wh): 28323.79 | Temp Deviation:   2.62 | Cost Savings ($): 2832.38
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -14.40
#     Energy Savings (Wh): 29267.59 | Temp Deviation:   2.49 | Cost Savings ($): 2926.76
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -14.12
#     Energy Savings (Wh): 29695.82 | Temp Deviation:   2.82 | Cost Savings ($): 2969.58
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -14.33
#     Energy Savings (Wh): 29443.23 | Temp Deviation:   2.73 | Cost Savings ($): 2944.32
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -12.37
#     Energy Savings (Wh): 31483.98 | Temp Deviation:   2.89 | Cost Savings ($): 3148.40
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -12.87
#     Energy Savings (Wh): 31072.80 | Temp Deviation:   3.10 | Cost Savings ($): 3107.28
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -14.51
#     Energy Savings (Wh): 29234.28 | Temp Deviation:   2.66 | Cost Savings ($): 2923.43
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -13.17
#     Energy Savings (Wh): 30633.85 | Temp Deviation:   2.78 | Cost Savings ($): 3063.38
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -13.13
#     Energy Savings (Wh): 30761.24 | Temp Deviation:   2.97 | Cost Savings ($): 3076.12
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -14.73
#     Energy Savings (Wh): 29059.56 | Temp Deviation:   2.76 | Cost Savings ($): 2905.96
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -13.90
# Avg Energy Savings (Wh): 29897.61
# Avg Temp Deviation: 2.78
# Avg Cost Savings ($): 2989.76
# Episode  19 | Total Reward:    -15.13 | Avg Loss:   0.1724 | Avg Entropy: 0.3740 | Validation Reward:    -13.90
# Eval Episode   1 | Steps:  500 | Total Reward:    -12.09
#     Energy Savings (Wh): 31855.95 | Temp Deviation:   3.10 | Cost Savings ($): 3185.60
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -12.41
#     Energy Savings (Wh): 31441.13 | Temp Deviation:   2.89 | Cost Savings ($): 3144.11
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -12.23
#     Energy Savings (Wh): 31664.23 | Temp Deviation:   3.00 | Cost Savings ($): 3166.42
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -12.71
#     Energy Savings (Wh): 31179.31 | Temp Deviation:   2.97 | Cost Savings ($): 3117.93
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -12.31
#     Energy Savings (Wh): 31606.21 | Temp Deviation:   3.04 | Cost Savings ($): 3160.62
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -13.24
#     Energy Savings (Wh): 30568.00 | Temp Deviation:   2.79 | Cost Savings ($): 3056.80
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -14.53
#     Energy Savings (Wh): 29306.02 | Temp Deviation:   2.87 | Cost Savings ($): 2930.60
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -12.95
#     Energy Savings (Wh): 30967.55 | Temp Deviation:   3.05 | Cost Savings ($): 3096.75
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -13.30
#     Energy Savings (Wh): 30452.67 | Temp Deviation:   2.67 | Cost Savings ($): 3045.27
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -13.48
#     Energy Savings (Wh): 30363.54 | Temp Deviation:   2.88 | Cost Savings ($): 3036.35
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -12.93
# Avg Energy Savings (Wh): 30940.46
# Avg Temp Deviation: 2.92
# Avg Cost Savings ($): 3094.05
# Episode  20 | Total Reward:    -12.10 | Avg Loss:   0.1451 | Avg Entropy: 0.3304 | Validation Reward:    -12.93
# Eval Episode   1 | Steps:  500 | Total Reward:    -13.14
#     Energy Savings (Wh): 30708.82 | Temp Deviation:   2.88 | Cost Savings ($): 3070.88
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -12.53
#     Energy Savings (Wh): 31318.41 | Temp Deviation:   2.89 | Cost Savings ($): 3131.84
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -12.58
#     Energy Savings (Wh): 31293.81 | Temp Deviation:   2.95 | Cost Savings ($): 3129.38
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -12.71
# ...
# Eval Episode 926 | Steps:  500 | Total Reward:     -8.32
#     Energy Savings (Wh): 40961.05 | Temp Deviation:   3.41 | Cost Savings ($): 4096.11
# --------------------------------------------------------------
# Eval Episode 927 | Steps:  500 | Total Reward:     -8.14
#     Energy Savings (Wh): 41179.26 | Temp Deviation:   3.48 | Cost Savings ($): 4117.93
# --------------------------------------------------------------
# Eval Episode 928 | Steps:  500 | Total Reward:     -7.83
#     Energy Savings (Wh): 41493.85 | Temp Deviation:   3.49 | Cost Savings ($): 4149.38
# --------------------------------------------------------------
# Eval Episode 929 | Steps:  500 | Total Reward:     -7.66
#     Energy Savings (Wh): 41709.33 | Temp Deviation:   3.60 | Cost Savings ($): 4170.93
# --------------------------------------------------------------
# Eval Episode 930 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41536.96 | Temp Deviation:   3.54 | Cost Savings ($): 4153.70
# --------------------------------------------------------------
# Eval Episode 931 | Steps:  500 | Total Reward:     -7.71
#     Energy Savings (Wh): 41633.12 | Temp Deviation:   3.55 | Cost Savings ($): 4163.31
# --------------------------------------------------------------
# Eval Episode 932 | Steps:  500 | Total Reward:     -7.78
#     Energy Savings (Wh): 41577.71 | Temp Deviation:   3.57 | Cost Savings ($): 4157.77
# --------------------------------------------------------------
# Eval Episode 933 | Steps:  500 | Total Reward:     -7.63
#     Energy Savings (Wh): 41736.88 | Temp Deviation:   3.58 | Cost Savings ($): 4173.69
# --------------------------------------------------------------
# Eval Episode 934 | Steps:  500 | Total Reward:     -7.92
#     Energy Savings (Wh): 41408.62 | Temp Deviation:   3.49 | Cost Savings ($): 4140.86
# --------------------------------------------------------------
# Eval Episode 935 | Steps:  500 | Total Reward:     -7.79
#     Energy Savings (Wh): 41548.05 | Temp Deviation:   3.52 | Cost Savings ($): 4154.80
# --------------------------------------------------------------
# Eval Episode 936 | Steps:  500 | Total Reward:     -8.17
#     Energy Savings (Wh): 41157.44 | Temp Deviation:   3.50 | Cost Savings ($): 4115.74
# --------------------------------------------------------------
# Eval Episode 937 | Steps:  500 | Total Reward:     -7.92
#     Energy Savings (Wh): 41408.91 | Temp Deviation:   3.51 | Cost Savings ($): 4140.89
# --------------------------------------------------------------
# Eval Episode 938 | Steps:  500 | Total Reward:     -7.84
#     Energy Savings (Wh): 41506.07 | Temp Deviation:   3.54 | Cost Savings ($): 4150.61
# --------------------------------------------------------------
# Eval Episode 939 | Steps:  500 | Total Reward:     -8.07
#     Energy Savings (Wh): 41261.32 | Temp Deviation:   3.50 | Cost Savings ($): 4126.13
# --------------------------------------------------------------
# Eval Episode 940 | Steps:  500 | Total Reward:     -7.65
#     Energy Savings (Wh): 41712.08 | Temp Deviation:   3.57 | Cost Savings ($): 4171.21
# --------------------------------------------------------------
# Eval Episode 941 | Steps:  500 | Total Reward:     -7.76
#     Energy Savings (Wh): 41580.36 | Temp Deviation:   3.53 | Cost Savings ($): 4158.04
# --------------------------------------------------------------
# Eval Episode 942 | Steps:  500 | Total Reward:     -7.97
#     Energy Savings (Wh): 41369.44 | Temp Deviation:   3.53 | Cost Savings ($): 4136.94
# --------------------------------------------------------------
# Eval Episode 943 | Steps:  500 | Total Reward:     -8.02
#     Energy Savings (Wh): 41325.45 | Temp Deviation:   3.54 | Cost Savings ($): 4132.55
# --------------------------------------------------------------
# Eval Episode 944 | Steps:  500 | Total Reward:     -7.90
#     Energy Savings (Wh): 41427.34 | Temp Deviation:   3.50 | Cost Savings ($): 4142.73
# --------------------------------------------------------------
# Eval Episode 945 | Steps:  500 | Total Reward:     -7.93
#     Energy Savings (Wh): 41400.45 | Temp Deviation:   3.52 | Cost Savings ($): 4140.05
# --------------------------------------------------------------
# Eval Episode 946 | Steps:  500 | Total Reward:     -7.99
#     Energy Savings (Wh): 41334.29 | Temp Deviation:   3.50 | Cost Savings ($): 4133.43
# --------------------------------------------------------------
# Eval Episode 947 | Steps:  500 | Total Reward:     -7.94
#     Energy Savings (Wh): 41390.01 | Temp Deviation:   3.51 | Cost Savings ($): 4139.00
# --------------------------------------------------------------
# Eval Episode 948 | Steps:  500 | Total Reward:     -7.77
#     Energy Savings (Wh): 41567.30 | Temp Deviation:   3.52 | Cost Savings ($): 4156.73
# --------------------------------------------------------------
# Eval Episode 949 | Steps:  500 | Total Reward:     -7.62
#     Energy Savings (Wh): 41748.03 | Temp Deviation:   3.59 | Cost Savings ($): 4174.80
# --------------------------------------------------------------
# Eval Episode 950 | Steps:  500 | Total Reward:     -7.92
#     Energy Savings (Wh): 41406.26 | Temp Deviation:   3.50 | Cost Savings ($): 4140.63
# --------------------------------------------------------------
# Eval Episode 951 | Steps:  500 | Total Reward:     -7.73
#     Energy Savings (Wh): 41612.39 | Temp Deviation:   3.54 | Cost Savings ($): 4161.24
# --------------------------------------------------------------
# Eval Episode 952 | Steps:  500 | Total Reward:     -7.78
#     Energy Savings (Wh): 41564.59 | Temp Deviation:   3.54 | Cost Savings ($): 4156.46
# --------------------------------------------------------------
# Eval Episode 953 | Steps:  500 | Total Reward:     -7.79
#     Energy Savings (Wh): 41557.27 | Temp Deviation:   3.55 | Cost Savings ($): 4155.73
# --------------------------------------------------------------
# Eval Episode 954 | Steps:  500 | Total Reward:     -7.51
#     Energy Savings (Wh): 41856.93 | Temp Deviation:   3.59 | Cost Savings ($): 4185.69
# --------------------------------------------------------------
# Eval Episode 955 | Steps:  500 | Total Reward:     -7.73
#     Energy Savings (Wh): 41618.81 | Temp Deviation:   3.54 | Cost Savings ($): 4161.88
# --------------------------------------------------------------
# Eval Episode 956 | Steps:  500 | Total Reward:     -7.87
#     Energy Savings (Wh): 41476.44 | Temp Deviation:   3.54 | Cost Savings ($): 4147.64
# --------------------------------------------------------------
# Eval Episode 957 | Steps:  500 | Total Reward:     -7.88
#     Energy Savings (Wh): 41462.46 | Temp Deviation:   3.54 | Cost Savings ($): 4146.25
# --------------------------------------------------------------
# Eval Episode 958 | Steps:  500 | Total Reward:     -7.60
#     Energy Savings (Wh): 41749.00 | Temp Deviation:   3.56 | Cost Savings ($): 4174.90
# --------------------------------------------------------------
# Eval Episode 959 | Steps:  500 | Total Reward:     -7.83
#     Energy Savings (Wh): 41514.85 | Temp Deviation:   3.54 | Cost Savings ($): 4151.49
# --------------------------------------------------------------
# Eval Episode 960 | Steps:  500 | Total Reward:     -7.71
#     Energy Savings (Wh): 41640.03 | Temp Deviation:   3.56 | Cost Savings ($): 4164.00
# --------------------------------------------------------------
# Eval Episode 961 | Steps:  500 | Total Reward:     -8.02
#     Energy Savings (Wh): 41326.76 | Temp Deviation:   3.55 | Cost Savings ($): 4132.68
# --------------------------------------------------------------
# Eval Episode 962 | Steps:  500 | Total Reward:     -8.04
#     Energy Savings (Wh): 41293.94 | Temp Deviation:   3.51 | Cost Savings ($): 4129.39
# --------------------------------------------------------------
# Eval Episode 963 | Steps:  500 | Total Reward:     -7.83
#     Energy Savings (Wh): 41503.29 | Temp Deviation:   3.52 | Cost Savings ($): 4150.33
# --------------------------------------------------------------
# Eval Episode 964 | Steps:  500 | Total Reward:     -7.89
#     Energy Savings (Wh): 41436.35 | Temp Deviation:   3.51 | Cost Savings ($): 4143.64
# --------------------------------------------------------------
# Eval Episode 965 | Steps:  500 | Total Reward:     -7.86
#     Energy Savings (Wh): 41485.83 | Temp Deviation:   3.55 | Cost Savings ($): 4148.58
# --------------------------------------------------------------
# Eval Episode 966 | Steps:  500 | Total Reward:     -7.69
#     Energy Savings (Wh): 41665.59 | Temp Deviation:   3.57 | Cost Savings ($): 4166.56
# --------------------------------------------------------------
# Eval Episode 967 | Steps:  500 | Total Reward:     -8.06
#     Energy Savings (Wh): 41267.51 | Temp Deviation:   3.51 | Cost Savings ($): 4126.75
# --------------------------------------------------------------
# Eval Episode 968 | Steps:  500 | Total Reward:     -7.57
#     Energy Savings (Wh): 41793.46 | Temp Deviation:   3.58 | Cost Savings ($): 4179.35
# --------------------------------------------------------------
# Eval Episode 969 | Steps:  500 | Total Reward:     -7.73
#     Energy Savings (Wh): 41612.49 | Temp Deviation:   3.55 | Cost Savings ($): 4161.25
# --------------------------------------------------------------
# Eval Episode 970 | Steps:  500 | Total Reward:     -7.86
#     Energy Savings (Wh): 41472.61 | Temp Deviation:   3.52 | Cost Savings ($): 4147.26
# --------------------------------------------------------------
# Eval Episode 971 | Steps:  500 | Total Reward:     -8.30
#     Energy Savings (Wh): 41007.11 | Temp Deviation:   3.45 | Cost Savings ($): 4100.71
# --------------------------------------------------------------
# Eval Episode 972 | Steps:  500 | Total Reward:     -7.98
#     Energy Savings (Wh): 41345.09 | Temp Deviation:   3.51 | Cost Savings ($): 4134.51
# --------------------------------------------------------------
# Eval Episode 973 | Steps:  500 | Total Reward:     -7.74
#     Energy Savings (Wh): 41599.77 | Temp Deviation:   3.54 | Cost Savings ($): 4159.98
# --------------------------------------------------------------
# Eval Episode 974 | Steps:  500 | Total Reward:     -7.82
#     Energy Savings (Wh): 41525.16 | Temp Deviation:   3.54 | Cost Savings ($): 4152.52
# --------------------------------------------------------------
# Eval Episode 975 | Steps:  500 | Total Reward:     -7.83
#     Energy Savings (Wh): 41504.28 | Temp Deviation:   3.52 | Cost Savings ($): 4150.43
# --------------------------------------------------------------
# Eval Episode 976 | Steps:  500 | Total Reward:     -7.91
#     Energy Savings (Wh): 41418.30 | Temp Deviation:   3.51 | Cost Savings ($): 4141.83
# --------------------------------------------------------------
# Eval Episode 977 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41518.97 | Temp Deviation:   3.50 | Cost Savings ($): 4151.90
# --------------------------------------------------------------
# Eval Episode 978 | Steps:  500 | Total Reward:     -7.67
#     Energy Savings (Wh): 41680.88 | Temp Deviation:   3.56 | Cost Savings ($): 4168.09
# --------------------------------------------------------------
# Eval Episode 979 | Steps:  500 | Total Reward:     -8.02
#     Energy Savings (Wh): 41304.36 | Temp Deviation:   3.50 | Cost Savings ($): 4130.44
# --------------------------------------------------------------
# Eval Episode 980 | Steps:  500 | Total Reward:     -7.73
#     Energy Savings (Wh): 41605.50 | Temp Deviation:   3.52 | Cost Savings ($): 4160.55
# --------------------------------------------------------------
# Eval Episode 981 | Steps:  500 | Total Reward:     -8.07
#     Energy Savings (Wh): 41252.05 | Temp Deviation:   3.49 | Cost Savings ($): 4125.20
# --------------------------------------------------------------
# Eval Episode 982 | Steps:  500 | Total Reward:     -7.78
#     Energy Savings (Wh): 41579.48 | Temp Deviation:   3.58 | Cost Savings ($): 4157.95
# --------------------------------------------------------------
# Eval Episode 983 | Steps:  500 | Total Reward:     -7.76
#     Energy Savings (Wh): 41584.54 | Temp Deviation:   3.55 | Cost Savings ($): 4158.45
# --------------------------------------------------------------
# Eval Episode 984 | Steps:  500 | Total Reward:     -7.82
#     Energy Savings (Wh): 41525.13 | Temp Deviation:   3.54 | Cost Savings ($): 4152.51
# --------------------------------------------------------------
# Eval Episode 985 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41534.29 | Temp Deviation:   3.54 | Cost Savings ($): 4153.43
# --------------------------------------------------------------
# Eval Episode 986 | Steps:  500 | Total Reward:     -7.69
#     Energy Savings (Wh): 41661.06 | Temp Deviation:   3.56 | Cost Savings ($): 4166.11
# --------------------------------------------------------------
# Eval Episode 987 | Steps:  500 | Total Reward:     -8.00
#     Energy Savings (Wh): 41335.63 | Temp Deviation:   3.53 | Cost Savings ($): 4133.56
# --------------------------------------------------------------
# Eval Episode 988 | Steps:  500 | Total Reward:     -8.31
#     Energy Savings (Wh): 41012.53 | Temp Deviation:   3.50 | Cost Savings ($): 4101.25
# --------------------------------------------------------------
# Eval Episode 989 | Steps:  500 | Total Reward:     -7.92
#     Energy Savings (Wh): 41417.57 | Temp Deviation:   3.53 | Cost Savings ($): 4141.76
# --------------------------------------------------------------
# Eval Episode 990 | Steps:  500 | Total Reward:     -8.19
#     Energy Savings (Wh): 41132.59 | Temp Deviation:   3.49 | Cost Savings ($): 4113.26
# --------------------------------------------------------------
# Eval Episode 991 | Steps:  500 | Total Reward:     -7.92
#     Energy Savings (Wh): 41406.07 | Temp Deviation:   3.49 | Cost Savings ($): 4140.61
# --------------------------------------------------------------
# Eval Episode 992 | Steps:  500 | Total Reward:     -7.92
#     Energy Savings (Wh): 41421.65 | Temp Deviation:   3.53 | Cost Savings ($): 4142.16
# --------------------------------------------------------------
# Eval Episode 993 | Steps:  500 | Total Reward:     -7.68
#     Energy Savings (Wh): 41681.26 | Temp Deviation:   3.57 | Cost Savings ($): 4168.13
# --------------------------------------------------------------
# Eval Episode 994 | Steps:  500 | Total Reward:     -7.44
#     Energy Savings (Wh): 41930.54 | Temp Deviation:   3.61 | Cost Savings ($): 4193.05
# --------------------------------------------------------------
# Eval Episode 995 | Steps:  500 | Total Reward:     -7.51
#     Energy Savings (Wh): 41864.88 | Temp Deviation:   3.61 | Cost Savings ($): 4186.49
# --------------------------------------------------------------
# Eval Episode 996 | Steps:  500 | Total Reward:     -7.56
#     Energy Savings (Wh): 41808.76 | Temp Deviation:   3.59 | Cost Savings ($): 4180.88
# --------------------------------------------------------------
# Eval Episode 997 | Steps:  500 | Total Reward:     -7.79
#     Energy Savings (Wh): 41554.68 | Temp Deviation:   3.54 | Cost Savings ($): 4155.47
# --------------------------------------------------------------
# Eval Episode 998 | Steps:  500 | Total Reward:     -7.89
#     Energy Savings (Wh): 41453.13 | Temp Deviation:   3.55 | Cost Savings ($): 4145.31
# --------------------------------------------------------------
# Eval Episode 999 | Steps:  500 | Total Reward:     -7.74
#     Energy Savings (Wh): 41604.26 | Temp Deviation:   3.54 | Cost Savings ($): 4160.43
# --------------------------------------------------------------
# Eval Episode 1000 | Steps:  500 | Total Reward:     -7.82
#     Energy Savings (Wh): 41513.58 | Temp Deviation:   3.51 | Cost Savings ($): 4151.36
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -7.86
# Avg Energy Savings (Wh): 41483.68
# Avg Temp Deviation: 3.53
# Avg Cost Savings ($): 4148.37
# Action counts: [4.9898e+04 4.7000e+01 2.9000e+01 2.6000e+01]
# Action probabilities: [9.9796e-01 9.4000e-04 5.8000e-04 5.2000e-04]
# Sample State: [17.01703704  0.68333333  1.         21.         60.        ]
# Action probabilities: [9.9988675e-01 6.5023545e-05 3.6135356e-05 1.2068822e-05]
