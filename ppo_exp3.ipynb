# %% [markdown]
# ### PPO with RandomSearch

# %%
import random
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from collections import deque
from sklearn.model_selection import train_test_split
import h5py
from sklearn.model_selection import KFold
import json

# %%
# Data Preprocessing Function

def preprocess_data(df):
    # Derive occupancy from lights (1 if lights > 0, else 0).
    df['Occupancy'] = df['lights'].apply(lambda x: 1 if x > 0 else 0)
    
    # Compute the average indoor temperature from columns T1 to T9.
    temp_cols = [f'T{i}' for i in range(1, 10)]
    df['Avg_T1_T9'] = df[temp_cols].mean(axis=1)
    
    # Compute HVAC energy consumption (Appliances minus lights).
    df['HVAC_energy'] = df['Appliances'] - df['lights']
    
    # Extract hour of day from the date column.
    df['date'] = pd.to_datetime(df['date'])
    df['Hour_of_day'] = df['date'].dt.hour
    
    # Select only the relevant features.
    relevant_features = ['Avg_T1_T9', 'T_out', 'Occupancy', 'Hour_of_day', 'HVAC_energy']
    df = df[relevant_features].copy()
    
    # Forward-fill any missing values.
    df.ffill(inplace=True)
    return df

# %%
# HVAC Environment with Dynamic Temperature and Scaled Reward

class HVACEnvironment:
    def __init__(self, dataframe, desired_temperature=22):
        self.df = dataframe.copy()
        self.desired_temperature = desired_temperature  
        self.observation_space_shape = self.df.shape[1]  # number of features
        self.action_space_n = 4  # 0 = Off, 1 = Low, 2 = Medium, 3 = High
        self.current_step = 0
        self.max_steps = len(self.df) - 1
        
        # Determine energy thresholds (for simulation purposes)
        self.energy_thresholds = {
            'Low': self.df['HVAC_energy'].quantile(0.25),
            'Medium': self.df['HVAC_energy'].quantile(0.5),
            'High': self.df['HVAC_energy'].quantile(0.75)
        }
        # Initialize a mutable indoor temperature.
        self.current_temp = self.df['Avg_T1_T9'].iloc[0]

    def reset(self, start_step=0):
        self.current_step = start_step
        # Reset the indoor temperature.
        self.current_temp = self.df['Avg_T1_T9'].iloc[self.current_step]
        return self._get_state()

    def _get_state(self):
        # Use the updated current_temp in place of the fixed dataset value.
        row = self.df.iloc[self.current_step].copy()
        row['Avg_T1_T9'] = self.current_temp
        return row.values

    def _get_reward(self, action, simulated_energy):
        # Scale the reward (divide by 1000) for numerical stability.
        lambda_factor = 0.9
        reward = -(simulated_energy + lambda_factor * abs(self.current_temp - self.desired_temperature)) / 1000.0
        return reward

    def _take_action(self, action):
        # Simulate HVAC energy consumption based on the chosen action.
        if action == 0:  # Off
            hvac_energy = np.random.uniform(0, 25)
        elif action == 1:  # Low
            hvac_energy = np.random.uniform(25, 100)
        elif action == 2:  # Medium
            hvac_energy = np.random.uniform(100, 300)
        elif action == 3:  # High
            hvac_energy = np.random.uniform(300, 500)
        else:
            raise ValueError("Invalid action.")
        return hvac_energy

    def step(self, action):
        simulated_energy = self._take_action(action)
        # Update the indoor temperature using a simple dynamics model.
        temp_change = (self.desired_temperature - self.current_temp) * 0.05
        self.current_temp += temp_change * (simulated_energy / 500.0)
        
        self.current_step += 1
        next_state = self._get_state()
        reward = self._get_reward(action, simulated_energy)
        done = self.current_step >= self.max_steps
        return next_state, reward, done, {"HVAC_energy": simulated_energy}

# %%
# Actor and Critic Networks for PPO

class Actor(nn.Module):
    def __init__(self, state_size, action_size):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)
        self.dropout = nn.Dropout(p=0.2)  # Dropout with 20% probability
        
    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = self.dropout(x)  # Apply dropout after the first layer
        x = torch.tanh(self.fc2(x))
        x = self.dropout(x)  # Apply dropout after the second layer
        logits = self.fc3(x)
        return logits

class Critic(nn.Module):
    def __init__(self, state_size):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 1)
        self.dropout = nn.Dropout(p=0.2)  # Dropout with 20% probability
        
    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = self.dropout(x)  # Apply dropout after the first layer
        x = torch.tanh(self.fc2(x))
        x = self.dropout(x)  # Apply dropout after the second layer
        value = self.fc3(x)
        return value

# %%
# PPO Agent (without epsilon)

class PPOAgent:
    def __init__(self, state_size, action_size, device):
        self.state_size = state_size
        self.action_size = action_size
        self.device = device

        # PPO hyperparameters.
        self.clip_epsilon = 0.2
        self.gamma = 0.99
        self.lamda = 0.95  # GAE lambda
        self.actor_lr = 1e-4
        self.critic_lr = 1e-3
        self.update_epochs = 4
        self.mini_batch_size = 64

        self.actor = Actor(state_size, action_size).to(device)
        self.critic = Critic(state_size).to(device)
        # self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=self.actor_lr)
        # self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=self.critic_lr)
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=self.actor_lr, weight_decay=1e-4)  # L2 regularization
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=self.critic_lr, weight_decay=1e-4)

    def select_action(self, state):
        state_tensor = torch.FloatTensor(state).to(self.device)
        logits = self.actor(state_tensor)
        dist = torch.distributions.Categorical(logits=logits)
        action = dist.sample()
        log_prob = dist.log_prob(action)
        value = self.critic(state_tensor)
        return action.item(), log_prob.item(), value.item()

# %%
# Compute Returns and Advantages (GAE)

def compute_gae(rewards, dones, values, gamma, lamda):
    advantages = []
    gae = 0
    # Append an extra value for ease (assume terminal state has 0 value)
    values = values + [0]
    for t in reversed(range(len(rewards))):
        delta = rewards[t] + gamma * values[t+1] * (1 - dones[t]) - values[t]
        gae = delta + gamma * lamda * (1 - dones[t]) * gae
        advantages.insert(0, gae)
    returns = [adv + val for adv, val in zip(advantages, values[:-1])]
    return returns, advantages

# %%
def train_ppo(env, agent, val_env, n_episodes=1000, max_t=500, cost_factor=0.10, patience=100):
    episode_rewards = []
    episode_losses = []
    entropy_vals = []
    overall_start_time = time.time()

    best_val_reward = -float('inf')  # Track the best validation reward
    no_improvement_count = 0  # Counter for early stopping

    for episode in range(n_episodes):
        ep_start_time = time.time()
        states, actions, log_probs, rewards, dones, values = [], [], [], [], [], []
        baseline_energy_sum, rl_energy_sum, temp_deviation_sum = 0.0, 0.0, 0.0

        state = env.reset()
        total_reward = 0

        for t in range(max_t):
            baseline_energy_sum += state[-1]
            temp_deviation_sum += abs(state[0] - env.desired_temperature)

            action, log_prob, value = agent.select_action(state)
            next_state, reward, done, info = env.step(action)

            rl_energy_sum += info.get("HVAC_energy", 0.0)
            states.append(state)
            actions.append(action)
            log_probs.append(log_prob)
            rewards.append(reward)
            dones.append(1 if done else 0)
            values.append(value)

            total_reward += reward
            state = next_state
            if done:
                break

        returns, advantages = compute_gae(rewards, dones, values, agent.gamma, agent.lamda)
        states_tensor = torch.FloatTensor(np.array(states)).to(agent.device)
        actions_tensor = torch.LongTensor(actions).to(agent.device)
        old_log_probs_tensor = torch.FloatTensor(log_probs).to(agent.device)
        returns_tensor = torch.FloatTensor(returns).to(agent.device)
        advantages_tensor = torch.FloatTensor(advantages).to(agent.device)
        advantages_tensor = (advantages_tensor - advantages_tensor.mean()) / (advantages_tensor.std() + 1e-8)

        losses, episode_entropy = [], []
        dataset_size = states_tensor.size(0)
        for _ in range(agent.update_epochs):
            permutation = np.random.permutation(dataset_size)
            for i in range(0, dataset_size, agent.mini_batch_size):
                indices = permutation[i:i+agent.mini_batch_size]
                batch_states = states_tensor[indices]
                batch_actions = actions_tensor[indices]
                batch_old_log_probs = old_log_probs_tensor[indices]
                batch_returns = returns_tensor[indices]
                batch_advantages = advantages_tensor[indices]

                logits = agent.actor(batch_states)
                dist = torch.distributions.Categorical(logits=logits)
                new_log_probs = dist.log_prob(batch_actions)
                entropy = dist.entropy().mean().item()
                episode_entropy.append(entropy)

                ratio = torch.exp(new_log_probs - batch_old_log_probs)
                surr1 = ratio * batch_advantages
                surr2 = torch.clamp(ratio, 1 - agent.clip_epsilon, 1 + agent.clip_epsilon) * batch_advantages
                actor_loss = -torch.min(surr1, surr2).mean()

                values_pred = agent.critic(batch_states).squeeze()
                critic_loss = nn.MSELoss()(values_pred, batch_returns)

                loss = actor_loss + 0.5 * critic_loss
                agent.actor_optimizer.zero_grad()
                agent.critic_optimizer.zero_grad()
                loss.backward()
                agent.actor_optimizer.step()
                agent.critic_optimizer.step()
                losses.append(loss.item())

        avg_loss = np.mean(losses)
        avg_entropy = np.mean(episode_entropy)
        entropy_vals.append(avg_entropy)
        episode_rewards.append(total_reward)
        episode_losses.append(avg_loss)

        # Evaluate on validation environment
        val_results = evaluate_ppo(val_env, agent, n_episodes=10, max_t=max_t, C_energy=cost_factor)
        avg_val_reward = np.mean([result["total_reward"] for result in val_results])

        print(f"Episode {episode+1:3d} | Total Reward: {total_reward:9.2f} | Avg Loss: {avg_loss:8.4f} | "
              f"Avg Entropy: {avg_entropy:6.4f} | Validation Reward: {avg_val_reward:9.2f}")

        # Early stopping logic
        if avg_val_reward > best_val_reward:
            best_val_reward = avg_val_reward
            no_improvement_count = 0
        else:
            no_improvement_count += 1
            if no_improvement_count >= patience:
                print(f"Early stopping triggered after {episode+1} episodes.")
                break

    overall_end_time = time.time()
    total_training_time = overall_end_time - overall_start_time
    print(f"Total training time: {total_training_time:.2f} seconds")

    return episode_rewards, episode_losses, entropy_vals

# %%
# PPO Evaluation Function with Extra Metrics

def evaluate_ppo(env, agent, n_episodes=50, max_t=500, C_energy=0.10):
    results = []
    for episode in range(n_episodes):
        state = env.reset()
        total_reward = 0.0
        t = 0
        baseline_energy_sum = 0.0
        rl_energy_sum = 0.0
        temp_deviation_sum = 0.0
        done = False
        while not done and t < max_t:
            baseline_energy_sum += state[-1]
            temp_deviation_sum += abs(state[0] - env.desired_temperature)
            action, _, _ = agent.select_action(state)
            state, reward, done, info = env.step(action)
            rl_energy_sum += info.get("HVAC_energy", 0.0)
            total_reward += reward
            t += 1
        
        energy_savings = baseline_energy_sum - rl_energy_sum
        avg_temp_deviation = temp_deviation_sum / (t + 1) if t > 0 else 0.0
        cost_savings = energy_savings * C_energy
        
        print(f"Eval Episode {episode+1:3d} | Steps: {t:4d} | Total Reward: {total_reward:9.2f}")
        print(f"    Energy Savings (Wh): {energy_savings:8.2f} | Temp Deviation: {avg_temp_deviation:6.2f} | "
              f"Cost Savings ($): {cost_savings:6.2f}")
        print("--------------------------------------------------------------")
        
        results.append({
            "episode": episode+1,
            "steps": t,
            "total_reward": total_reward,
            "energy_savings": energy_savings,
            "avg_temp_deviation": avg_temp_deviation,
            "cost_savings": cost_savings
        })
        
    avg_reward = np.mean([r["total_reward"] for r in results])
    avg_energy_savings = np.mean([r["energy_savings"] for r in results])
    avg_temp_deviation = np.mean([r["avg_temp_deviation"] for r in results])
    avg_cost_savings = np.mean([r["cost_savings"] for r in results])
    print("\nFinal Average Evaluation Metrics over all evaluation episodes:")
    print(f"Avg Total Reward: {avg_reward:.2f}")
    print(f"Avg Energy Savings (Wh): {avg_energy_savings:.2f}")
    print(f"Avg Temp Deviation: {avg_temp_deviation:.2f}")
    print(f"Avg Cost Savings ($): {avg_cost_savings:.2f}")
    
    return results

# %%
# Evaluation Functions: Energy Consumption Comparison

def evaluate_energy_consumption(env, agent, n_episodes=1000, max_t=500):
    optimized_energy = []
    for episode in range(n_episodes):
        state = env.reset()
        total_energy = 0
        for t in range(max_t):
            action, log_prob, value = agent.select_action(state)
            state, reward, done, info = env.step(action)
            total_energy += info["HVAC_energy"]
            if done:
                break
        optimized_energy.append(total_energy)
    return optimized_energy

def evaluate_baseline_energy(env, fixed_action=2, n_episodes=100, max_t=500):
    baseline_energy = []
    for episode in range(n_episodes):
        state = env.reset()
        total_energy = 0
        for t in range(max_t):
            state, reward, done, info = env.step(fixed_action)
            total_energy += info["HVAC_energy"]
            if done:
                break
        baseline_energy.append(total_energy)
    return baseline_energy

def plot_energy_comparison(optimized_energy, baseline_energy):
    episodes = np.arange(len(optimized_energy))
    plt.figure(figsize=(8, 6))
    plt.plot(episodes, optimized_energy, label="Optimized Energy Consumption", marker='o')
    plt.plot(episodes, baseline_energy, label="Baseline Energy Consumption", marker='x')
    plt.xlabel("Evaluation Episode")
    plt.ylabel("Total HVAC Energy Consumption (Wh)")
    plt.title("Optimized vs. Baseline HVAC Energy Consumption")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Action Analysis and Visualization Functions

def analyze_action_distribution(env, agent, n_episodes=1000, max_t=500):
    action_counts = np.zeros(agent.action_size)
    for episode in range(n_episodes):
        state = env.reset()
        for t in range(max_t):
            action, log_prob, value = agent.select_action(state)
            action_counts[action] += 1
            state, reward, done, _ = env.step(action)
            if done:
                break
    action_probabilities = action_counts / np.sum(action_counts)
    
    # Plot histogram/bar chart
    actions = np.arange(agent.action_size)
    plt.figure(figsize=(8, 4))
    plt.bar(actions, action_counts, tick_label=["Off", "Low", "Medium", "High"], color='skyblue')
    plt.xlabel("Actions")
    plt.ylabel("Frequency")
    plt.title("Action Selection Frequency over {} Episodes".format(n_episodes))
    plt.show()
    
    return action_counts, action_probabilities

def visualize_policy_for_state(env, agent, sample_state=None):
    if sample_state is None:
        sample_state = env.reset()
    
    state_tensor = torch.FloatTensor(sample_state).to(agent.device)
    logits = agent.actor(state_tensor)
    probabilities = torch.softmax(logits, dim=-1).detach().cpu().numpy()
    
    actions = np.arange(agent.action_size)
    plt.figure(figsize=(6, 4))
    plt.bar(actions, probabilities, tick_label=["Off", "Low", "Medium", "High"], color='magenta')
    plt.xlabel("Actions")
    plt.ylabel("Probability")
    plt.title("Action Probabilities for a Sample State")
    plt.ylim([0, 1])
    plt.show()
    
    print("Sample State:", sample_state)
    print("Action probabilities:", probabilities)

# %%
# Plotting Functions 

def plot_training_results(rewards, losses, entropy_vals):
    episodes = np.arange(len(rewards))
    
    # Plot Total Reward per Episode
    plt.figure(figsize=(8, 6))
    plt.plot(episodes, rewards, label="Total Reward")
    plt.title("Total Reward per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # Plot Average Loss per Episode
    plt.figure(figsize=(8, 6))
    plt.plot(episodes, losses, label="Loss", color="red")
    plt.title("Average Loss per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # Plot Entropy Evolution
    plt.figure(figsize=(8, 6))
    plt.plot(episodes, entropy_vals, label="Entropy", color="green")
    plt.title("Entropy Evolution")
    plt.xlabel("Episode")
    plt.ylabel("Entropy")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def random_search_ppo(env_train, val_env, state_size, action_size, device, num_trials=10, tuning_episodes=50):
    # Define the ranges for random search
    best_reward = -np.inf
    best_params = None
    
    for trial in range(num_trials):
        # Randomly sample hyperparameters
        actor_lr = 10 ** random.uniform(-5, -3)  # log-uniform between 1e-5 and 1e-3
        critic_lr = 10 ** random.uniform(-5, -2)  # log-uniform between 1e-5 and 1e-2
        clip_epsilon = random.uniform(0.1, 0.3)
        update_epochs = random.randint(2, 8)
        
        print(f"Trial {trial+1}: actor_lr={actor_lr:.1e}, critic_lr={critic_lr:.1e}, clip_epsilon={clip_epsilon:.2f}, update_epochs={update_epochs}")
        
        # Instantiate a new PPO agent with these hyperparameters
        agent = PPOAgent(state_size, action_size, device)
        agent.actor_lr = actor_lr
        agent.critic_lr = critic_lr
        agent.clip_epsilon = clip_epsilon
        agent.update_epochs = update_epochs
        agent.actor_optimizer = optim.Adam(agent.actor.parameters(), lr=actor_lr)
        agent.critic_optimizer = optim.Adam(agent.critic.parameters(), lr=critic_lr)
        
        # Run training for a short tuning session
        rewards, _, _ = train_ppo(env_train, agent, val_env, n_episodes=tuning_episodes, max_t=500, cost_factor=0.10, patience=5)
        avg_reward = np.mean(rewards[-10:])  # average reward of the last 10 episodes
        
        print(f"Trial {trial+1} average reward (last 10 episodes): {avg_reward:.2f}\n")
        if avg_reward > best_reward:
            best_reward = avg_reward
            best_params = {
                "actor_lr": actor_lr,
                "critic_lr": critic_lr,
                "clip_epsilon": clip_epsilon,
                "update_epochs": update_epochs
            }
    print("Best hyperparameters found:")
    print(best_params)
    print(f"Best average reward: {best_reward:.2f}")
    return best_params

# %%
# Function to save the PPO model as .h5 format
def save_model_as_h5(agent, filepath):
    # Save the actor and critic state dictionaries
    actor_state_dict = agent.actor.state_dict()
    critic_state_dict = agent.critic.state_dict()
    
    # Create an HDF5 file
    with h5py.File(filepath, 'w') as h5file:
        # Save actor state dictionary
        actor_group = h5file.create_group('actor')
        for key, value in actor_state_dict.items():
            actor_group.create_dataset(key, data=value.cpu().numpy())
        
        # Save critic state dictionary
        critic_group = h5file.create_group('critic')
        for key, value in critic_state_dict.items():
            critic_group.create_dataset(key, data=value.cpu().numpy())
    
    print(f"Model saved to {filepath}")

# %%
def kfold_cross_validation(df, k=5, n_episodes=1000, max_t=500, cost_factor=0.10, patience=10):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    fold_results = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(df)):
        print(f"\n=== Fold {fold + 1}/{k} ===")

        train_data = df.iloc[train_idx]
        val_data = df.iloc[val_idx]

        env_train = HVACEnvironment(train_data, desired_temperature=22)
        env_val = HVACEnvironment(val_data, desired_temperature=22)

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        state_size = env_train.observation_space_shape
        action_size = env_train.action_space_n
        ppo_agent = PPOAgent(state_size, action_size, device)

        print("\nTraining PPO with Early Stopping...")
        train_rewards, train_losses, entropy_vals = train_ppo(
            env_train, ppo_agent, env_val, n_episodes=n_episodes, max_t=max_t, cost_factor=cost_factor, patience=patience
        )

        val_results = evaluate_ppo(env_val, ppo_agent, n_episodes=100, max_t=max_t, C_energy=cost_factor)
        val_rewards = [result["total_reward"] for result in val_results]
        avg_val_reward = np.mean(val_rewards)
        print(f"Fold {fold + 1} Average Validation Reward: {avg_val_reward:.2f}")

        fold_results.append({
            "fold": fold + 1,
            "train_rewards": train_rewards,
            "val_rewards": val_rewards,
            "avg_val_reward": avg_val_reward
        })

    return fold_results

# %%
if __name__ == "__main__":
    # Load and Preprocess the Data 
    df = pd.read_csv("data/raw_data.csv")
    df = preprocess_data(df)
    
    # Data Split: 70% Train, 15% Test, 15% Validation 
    print("\nSplitting data into train, test, and validation sets...")
    train_data, temp_data = train_test_split(df, test_size=0.30, random_state=42)
    test_data, val_data = train_test_split(temp_data, test_size=0.50, random_state=42)
    print(f"Train samples: {len(train_data)}")
    print(f"Test samples: {len(test_data)}")
    print(f"Validation samples: {len(val_data)}")
    
    # Create Environments for each Data Split 
    env_train = HVACEnvironment(train_data, desired_temperature=22)
    env_test = HVACEnvironment(test_data, desired_temperature=22)
    env_val = HVACEnvironment(val_data, desired_temperature=22)
    
    # Initialize the PPO Agent 
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    state_size = env_train.observation_space_shape
    action_size = env_train.action_space_n

    # Random Search Hyperparameter Tuning 
    print("\nStarting Random Search Hyperparameter Tuning...")
    best_params = random_search_ppo(env_train, env_val, state_size, action_size, device, num_trials=10, tuning_episodes=50)
    
    # Retrain PPO with Best Hyperparameters 
    print("\nRetraining PPO with the best hyperparameters...")
    best_agent = PPOAgent(state_size, action_size, device)
    best_agent.actor_lr = best_params["actor_lr"]
    best_agent.critic_lr = best_params["critic_lr"]
    best_agent.clip_epsilon = best_params["clip_epsilon"]
    best_agent.update_epochs = best_params["update_epochs"]
    best_agent.actor_optimizer = optim.Adam(best_agent.actor.parameters(), lr=best_params["actor_lr"])
    best_agent.critic_optimizer = optim.Adam(best_agent.critic.parameters(), lr=best_params["critic_lr"])
    
    # Train the PPO Agent on the Training Split 
    print("\nTraining PPO on the full training split...")
    train_rewards, train_losses, entropy_vals = train_ppo(
        env_train, best_agent, env_val, n_episodes=10000, max_t=500, cost_factor=0.10, patience=100
    )
    
    # Save the trained model
    save_model_as_h5(best_agent, "/Users/amalshar/Desktop/USD/Spring 2025/Applied Reinforecement Learning/RL Project/exp3_ppo_model.h5")
    
    # Save training results to a JSON file
    results = {
        "rewards": train_rewards,
        "losses": train_losses,
        "entropy": entropy_vals
    }
    with open("/Users/amalshar/Desktop/USD/Spring 2025/Applied Reinforecement Learning/RL Project/exp3_results.json", "w") as f:
        json.dump(results, f)
    print("Training results saved to exp3_results.json")
    
    # Evaluate the Trained PPO Model 
    print("\nEvaluating PPO on the test split...")
    test_results = evaluate_ppo(env_test, best_agent, n_episodes=1000, max_t=500, C_energy=0.10)
    
    print("\nEvaluating PPO on the validation split...")
    val_results = evaluate_ppo(env_val, best_agent, n_episodes=1000, max_t=500, C_energy=0.10)
    
    # Extract total rewards from test_results
    test_rewards = [result["total_reward"] for result in test_results]
    
    # Plot Results 
    plot_training_results(train_rewards, train_losses, entropy_vals)
    
    optimized_energy = evaluate_energy_consumption(env_test, best_agent, n_episodes=100, max_t=500)
    baseline_energy = evaluate_baseline_energy(env_test, fixed_action=2, n_episodes=100, max_t=500)
    plot_energy_comparison(optimized_energy, baseline_energy)
    
    action_counts, action_probs = analyze_action_distribution(env_test, best_agent, n_episodes=100, max_t=500)
    print("Action counts:", action_counts)
    print("Action probabilities:", action_probs)
    visualize_policy_for_state(env_test, best_agent)
# Out:
# Splitting data into train, test, and validation sets...
# Train samples: 13814
# Test samples: 2960
# Validation samples: 2961
#
# Starting Random Search Hyperparameter Tuning...
# Trial 1: actor_lr=1.2e-05, critic_lr=9.5e-03, clip_epsilon=0.21, update_epochs=5
# Eval Episode   1 | Steps:  500 | Total Reward:    -77.69
#     Energy Savings (Wh): -29643.29 | Temp Deviation:   0.67 | Cost Savings ($): -2964.33
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -78.33
#     Energy Savings (Wh): -30305.89 | Temp Deviation:   0.62 | Cost Savings ($): -3030.59
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -71.01
#     Energy Savings (Wh): -22968.24 | Temp Deviation:   0.65 | Cost Savings ($): -2296.82
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -79.08
#     Energy Savings (Wh): -31032.71 | Temp Deviation:   0.66 | Cost Savings ($): -3103.27
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -79.95
#     Energy Savings (Wh): -31913.52 | Temp Deviation:   0.64 | Cost Savings ($): -3191.35
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -81.36
#     Energy Savings (Wh): -33337.71 | Temp Deviation:   0.61 | Cost Savings ($): -3333.77
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -76.57
#     Energy Savings (Wh): -28522.92 | Temp Deviation:   0.66 | Cost Savings ($): -2852.29
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -84.62
#     Energy Savings (Wh): -36605.00 | Temp Deviation:   0.59 | Cost Savings ($): -3660.50
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -73.78
#     Energy Savings (Wh): -25702.35 | Temp Deviation:   0.74 | Cost Savings ($): -2570.23
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -81.87
#     Energy Savings (Wh): -33871.98 | Temp Deviation:   0.57 | Cost Savings ($): -3387.20
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -78.42
# Avg Energy Savings (Wh): -30390.36
# Avg Temp Deviation: 0.64
# Avg Cost Savings ($): -3039.04
# Episode   1 | Total Reward:    -83.29 | Avg Loss:   0.3450 | Avg Entropy: 1.3628 | Validation Reward:    -78.42
# Eval Episode   1 | Steps:  500 | Total Reward:    -80.50
#     Energy Savings (Wh): -32479.96 | Temp Deviation:   0.61 | Cost Savings ($): -3248.00
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -79.45
#     Energy Savings (Wh): -31402.60 | Temp Deviation:   0.67 | Cost Savings ($): -3140.26
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -79.16
#     Energy Savings (Wh): -31136.01 | Temp Deviation:   0.63 | Cost Savings ($): -3113.60
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -74.73
#     Energy Savings (Wh): -26692.79 | Temp Deviation:   0.64 | Cost Savings ($): -2669.28
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -74.27
#     Energy Savings (Wh): -26168.63 | Temp Deviation:   0.78 | Cost Savings ($): -2616.86
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -78.08
#     Energy Savings (Wh): -30078.81 | Temp Deviation:   0.56 | Cost Savings ($): -3007.88
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -70.56
#     Energy Savings (Wh): -22510.46 | Temp Deviation:   0.66 | Cost Savings ($): -2251.05
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -78.97
#     Energy Savings (Wh): -30955.28 | Temp Deviation:   0.59 | Cost Savings ($): -3095.53
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -73.15
#     Energy Savings (Wh): -25105.15 | Temp Deviation:   0.66 | Cost Savings ($): -2510.52
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -74.00
#     Energy Savings (Wh): -25963.31 | Temp Deviation:   0.64 | Cost Savings ($): -2596.33
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -76.29
# Avg Energy Savings (Wh): -28249.30
# Avg Temp Deviation: 0.64
# Avg Cost Savings ($): -2824.93
# Episode   2 | Total Reward:    -74.39 | Avg Loss:   0.6176 | Avg Entropy: 1.3602 | Validation Reward:    -76.29
# Eval Episode   1 | Steps:  500 | Total Reward:    -78.73
#     Energy Savings (Wh): -30700.79 | Temp Deviation:   0.62 | Cost Savings ($): -3070.08
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -72.27
#     Energy Savings (Wh): -24208.34 | Temp Deviation:   0.70 | Cost Savings ($): -2420.83
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -79.29
#     Energy Savings (Wh): -31280.50 | Temp Deviation:   0.59 | Cost Savings ($): -3128.05
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -72.15
#     Energy Savings (Wh): -24084.04 | Temp Deviation:   0.72 | Cost Savings ($): -2408.40
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -77.97
#     Energy Savings (Wh): -29966.55 | Temp Deviation:   0.57 | Cost Savings ($): -2996.66
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -75.20
#     Energy Savings (Wh): -27192.87 | Temp Deviation:   0.59 | Cost Savings ($): -2719.29
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -69.89
#     Energy Savings (Wh): -21836.84 | Temp Deviation:   0.69 | Cost Savings ($): -2183.68
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -75.93
#     Energy Savings (Wh): -27929.09 | Temp Deviation:   0.56 | Cost Savings ($): -2792.91
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -69.09
#     Energy Savings (Wh): -21020.37 | Temp Deviation:   0.72 | Cost Savings ($): -2102.04
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -72.93
#     Energy Savings (Wh): -24877.93 | Temp Deviation:   0.68 | Cost Savings ($): -2487.79
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -74.35
# Avg Energy Savings (Wh): -26309.73
# Avg Temp Deviation: 0.64
# Avg Cost Savings ($): -2630.97
# Episode   3 | Total Reward:    -79.72 | Avg Loss:   0.6969 | Avg Entropy: 1.3575 | Validation Reward:    -74.35
# Eval Episode   1 | Steps:  500 | Total Reward:    -71.74
#     Energy Savings (Wh): -23680.32 | Temp Deviation:   0.70 | Cost Savings ($): -2368.03
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -71.97
#     Energy Savings (Wh): -23861.23 | Temp Deviation:   0.80 | Cost Savings ($): -2386.12
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -69.66
#     Energy Savings (Wh): -21610.74 | Temp Deviation:   0.68 | Cost Savings ($): -2161.07
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -77.49
#     Energy Savings (Wh): -29465.06 | Temp Deviation:   0.61 | Cost Savings ($): -2946.51
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -74.10
#     Energy Savings (Wh): -26050.80 | Temp Deviation:   0.68 | Cost Savings ($): -2605.08
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -76.08
#     Energy Savings (Wh): -28041.65 | Temp Deviation:   0.65 | Cost Savings ($): -2804.17
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -73.48
#     Energy Savings (Wh): -25446.09 | Temp Deviation:   0.64 | Cost Savings ($): -2544.61
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -71.50
#     Energy Savings (Wh): -23446.68 | Temp Deviation:   0.68 | Cost Savings ($): -2344.67
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -71.99
#     Energy Savings (Wh): -23941.68 | Temp Deviation:   0.66 | Cost Savings ($): -2394.17
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -77.41
#     Energy Savings (Wh): -29397.04 | Temp Deviation:   0.59 | Cost Savings ($): -2939.70
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -73.54
# Avg Energy Savings (Wh): -25494.13
# Avg Temp Deviation: 0.67
# Avg Cost Savings ($): -2549.41
# Episode   4 | Total Reward:    -76.07 | Avg Loss:   0.7060 | Avg Entropy: 1.3542 | Validation Reward:    -73.54
# Eval Episode   1 | Steps:  500 | Total Reward:    -70.18
#     Energy Savings (Wh): -22119.46 | Temp Deviation:   0.69 | Cost Savings ($): -2211.95
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -74.29
#     Energy Savings (Wh): -26242.69 | Temp Deviation:   0.67 | Cost Savings ($): -2624.27
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -69.54
#     Energy Savings (Wh): -21507.42 | Temp Deviation:   0.64 | Cost Savings ($): -2150.74
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -73.42
#     Energy Savings (Wh): -25391.60 | Temp Deviation:   0.64 | Cost Savings ($): -2539.16
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -72.49
#     Energy Savings (Wh): -24431.84 | Temp Deviation:   0.70 | Cost Savings ($): -2443.18
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -81.18
#     Energy Savings (Wh): -33141.36 | Temp Deviation:   0.66 | Cost Savings ($): -3314.14
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -78.88
#     Energy Savings (Wh): -30847.46 | Temp Deviation:   0.63 | Cost Savings ($): -3084.75
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -72.45
#     Energy Savings (Wh): -24406.42 | Temp Deviation:   0.67 | Cost Savings ($): -2440.64
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -74.01
#     Energy Savings (Wh): -25949.10 | Temp Deviation:   0.71 | Cost Savings ($): -2594.91
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -72.46
#     Energy Savings (Wh): -24424.87 | Temp Deviation:   0.64 | Cost Savings ($): -2442.49
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -73.89
# Avg Energy Savings (Wh): -25846.22
# Avg Temp Deviation: 0.66
# Avg Cost Savings ($): -2584.62
# Episode   5 | Total Reward:    -74.09 | Avg Loss:   0.8142 | Avg Entropy: 1.3505 | Validation Reward:    -73.89
# Eval Episode   1 | Steps:  500 | Total Reward:    -74.67
#     Energy Savings (Wh): -26654.27 | Temp Deviation:   0.60 | Cost Savings ($): -2665.43
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -70.55
#     Energy Savings (Wh): -22482.74 | Temp Deviation:   0.71 | Cost Savings ($): -2248.27
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -75.58
#     Energy Savings (Wh): -27564.51 | Temp Deviation:   0.60 | Cost Savings ($): -2756.45
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -71.55
#     Energy Savings (Wh): -23490.78 | Temp Deviation:   0.69 | Cost Savings ($): -2349.08
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -69.43
#     Energy Savings (Wh): -21429.29 | Temp Deviation:   0.57 | Cost Savings ($): -2142.93
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -73.20
#     Energy Savings (Wh): -25156.59 | Temp Deviation:   0.66 | Cost Savings ($): -2515.66
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -73.37
#     Energy Savings (Wh): -25312.87 | Temp Deviation:   0.68 | Cost Savings ($): -2531.29
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -66.31
#     Energy Savings (Wh): -18228.27 | Temp Deviation:   0.74 | Cost Savings ($): -1822.83
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -66.90
#     Energy Savings (Wh): -18847.39 | Temp Deviation:   0.69 | Cost Savings ($): -1884.74
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -70.68
#     Energy Savings (Wh): -22668.62 | Temp Deviation:   0.60 | Cost Savings ($): -2266.86
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -71.22
# Avg Energy Savings (Wh): -23183.53
# Avg Temp Deviation: 0.65
# Avg Cost Savings ($): -2318.35
# Episode   6 | Total Reward:    -70.98 | Avg Loss:   1.0260 | Avg Entropy: 1.3488 | Validation Reward:    -71.22
# Eval Episode   1 | Steps:  500 | Total Reward:    -61.17
#     Energy Savings (Wh): -13067.04 | Temp Deviation:   0.79 | Cost Savings ($): -1306.70
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -69.18
#     Energy Savings (Wh): -21103.43 | Temp Deviation:   0.72 | Cost Savings ($): -2110.34
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -72.01
#     Energy Savings (Wh): -23957.22 | Temp Deviation:   0.69 | Cost Savings ($): -2395.72
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -70.37
#     Energy Savings (Wh): -22297.38 | Temp Deviation:   0.71 | Cost Savings ($): -2229.74
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -72.88
#     Energy Savings (Wh): -24820.07 | Temp Deviation:   0.70 | Cost Savings ($): -2482.01
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -64.21
#     Energy Savings (Wh): -16117.92 | Temp Deviation:   0.77 | Cost Savings ($): -1611.79
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -69.97
#     Energy Savings (Wh): -21917.73 | Temp Deviation:   0.69 | Cost Savings ($): -2191.77
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -64.83
#     Energy Savings (Wh): -16688.72 | Temp Deviation:   0.87 | Cost Savings ($): -1668.87
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -77.08
#     Energy Savings (Wh): -29061.22 | Temp Deviation:   0.60 | Cost Savings ($): -2906.12
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -68.87
#     Energy Savings (Wh): -20802.83 | Temp Deviation:   0.71 | Cost Savings ($): -2080.28
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -69.06
# Avg Energy Savings (Wh): -20983.36
# Avg Temp Deviation: 0.72
# Avg Cost Savings ($): -2098.34
# Episode   7 | Total Reward:    -70.05 | Avg Loss:   1.1230 | Avg Entropy: 1.3445 | Validation Reward:    -69.06
# Eval Episode   1 | Steps:  500 | Total Reward:    -70.27
#     Energy Savings (Wh): -22217.96 | Temp Deviation:   0.68 | Cost Savings ($): -2221.80
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -67.35
#     Energy Savings (Wh): -19249.88 | Temp Deviation:   0.78 | Cost Savings ($): -1924.99
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -74.48
#     Energy Savings (Wh): -26438.83 | Temp Deviation:   0.67 | Cost Savings ($): -2643.88
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -70.79
#     Energy Savings (Wh): -22708.15 | Temp Deviation:   0.75 | Cost Savings ($): -2270.81
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -70.54
#     Energy Savings (Wh): -22455.30 | Temp Deviation:   0.74 | Cost Savings ($): -2245.53
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -74.47
#     Energy Savings (Wh): -26428.76 | Temp Deviation:   0.66 | Cost Savings ($): -2642.88
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -69.57
#     Energy Savings (Wh): -21513.36 | Temp Deviation:   0.70 | Cost Savings ($): -2151.34
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -66.75
#     Energy Savings (Wh): -18700.43 | Temp Deviation:   0.67 | Cost Savings ($): -1870.04
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -70.40
#     Energy Savings (Wh): -22360.66 | Temp Deviation:   0.64 | Cost Savings ($): -2236.07
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -69.35
#     Energy Savings (Wh): -21253.26 | Temp Deviation:   0.78 | Cost Savings ($): -2125.33
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -70.40
# Avg Energy Savings (Wh): -22332.66
# Avg Temp Deviation: 0.71
# Avg Cost Savings ($): -2233.27
# Episode   8 | Total Reward:    -74.96 | Avg Loss:   1.1546 | Avg Entropy: 1.3410 | Validation Reward:    -70.40
# Eval Episode   1 | Steps:  500 | Total Reward:    -65.47
#     Energy Savings (Wh): -17409.80 | Temp Deviation:   0.70 | Cost Savings ($): -1740.98
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -69.14
#     Energy Savings (Wh): -21075.76 | Temp Deviation:   0.70 | Cost Savings ($): -2107.58
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -67.29
#     Energy Savings (Wh): -19227.99 | Temp Deviation:   0.71 | Cost Savings ($): -1922.80
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -69.70
#     Energy Savings (Wh): -21641.28 | Temp Deviation:   0.70 | Cost Savings ($): -2164.13
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -71.18
#     Energy Savings (Wh): -23149.50 | Temp Deviation:   0.63 | Cost Savings ($): -2314.95
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -72.76
#     Energy Savings (Wh): -24744.53 | Temp Deviation:   0.60 | Cost Savings ($): -2474.45
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -71.20
#     Energy Savings (Wh): -23171.40 | Temp Deviation:   0.62 | Cost Savings ($): -2317.14
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -67.48
#     Energy Savings (Wh): -19438.47 | Temp Deviation:   0.66 | Cost Savings ($): -1943.85
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -65.85
#     Energy Savings (Wh): -17833.85 | Temp Deviation:   0.60 | Cost Savings ($): -1783.39
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -72.00
#     Energy Savings (Wh): -23910.71 | Temp Deviation:   0.76 | Cost Savings ($): -2391.07
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -69.21
# Avg Energy Savings (Wh): -21160.33
# Avg Temp Deviation: 0.67
# Avg Cost Savings ($): -2116.03
# Episode   9 | Total Reward:    -63.92 | Avg Loss:   1.2200 | Avg Entropy: 1.3393 | Validation Reward:    -69.21
# Eval Episode   1 | Steps:  500 | Total Reward:    -66.51
#     Energy Savings (Wh): -18476.96 | Temp Deviation:   0.65 | Cost Savings ($): -1847.70
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -66.37
#     Energy Savings (Wh): -18313.08 | Temp Deviation:   0.70 | Cost Savings ($): -1831.31
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -70.95
#     Energy Savings (Wh): -22880.07 | Temp Deviation:   0.72 | Cost Savings ($): -2288.01
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -65.85
#     Energy Savings (Wh): -17771.92 | Temp Deviation:   0.73 | Cost Savings ($): -1777.19
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -73.01
#     Energy Savings (Wh): -24966.44 | Temp Deviation:   0.66 | Cost Savings ($): -2496.64
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -68.35
#     Energy Savings (Wh): -20314.80 | Temp Deviation:   0.64 | Cost Savings ($): -2031.48
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -64.49
#     Energy Savings (Wh): -16402.94 | Temp Deviation:   0.76 | Cost Savings ($): -1640.29
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -72.13
#     Energy Savings (Wh): -24112.72 | Temp Deviation:   0.61 | Cost Savings ($): -2411.27
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -68.58
#     Energy Savings (Wh): -20540.31 | Temp Deviation:   0.64 | Cost Savings ($): -2054.03
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -67.55
#     Energy Savings (Wh): -19493.43 | Temp Deviation:   0.68 | Cost Savings ($): -1949.34
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -68.38
# Avg Energy Savings (Wh): -20327.27
# Avg Temp Deviation: 0.68
# Avg Cost Savings ($): -2032.73
# Episode  10 | Total Reward:    -71.52 | Avg Loss:   1.3480 | Avg Entropy: 1.3364 | Validation Reward:    -68.38
# Eval Episode   1 | Steps:  500 | Total Reward:    -68.99
#     Energy Savings (Wh): -20935.12 | Temp Deviation:   0.68 | Cost Savings ($): -2093.51
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -71.09
#     Energy Savings (Wh): -23011.34 | Temp Deviation:   0.74 | Cost Savings ($): -2301.13
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -64.59
#     Energy Savings (Wh): -16507.98 | Temp Deviation:   0.74 | Cost Savings ($): -1650.80
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -69.39
#     Energy Savings (Wh): -21334.08 | Temp Deviation:   0.68 | Cost Savings ($): -2133.41
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -69.07
#     Energy Savings (Wh): -21038.29 | Temp Deviation:   0.63 | Cost Savings ($): -2103.83
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -71.06
#     Energy Savings (Wh): -23011.59 | Temp Deviation:   0.68 | Cost Savings ($): -2301.16
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -62.31
#     Energy Savings (Wh): -14223.59 | Temp Deviation:   0.75 | Cost Savings ($): -1422.36
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -71.53
#     Energy Savings (Wh): -23466.65 | Temp Deviation:   0.71 | Cost Savings ($): -2346.66
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -66.34
#     Energy Savings (Wh): -18269.65 | Temp Deviation:   0.72 | Cost Savings ($): -1826.97
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -62.78
#     Energy Savings (Wh): -14719.42 | Temp Deviation:   0.70 | Cost Savings ($): -1471.94
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -67.71
# Avg Energy Savings (Wh): -19651.77
# Avg Temp Deviation: 0.70
# Avg Cost Savings ($): -1965.18
# Episode  11 | Total Reward:    -65.32 | Avg Loss:   1.4342 | Avg Entropy: 1.3350 | Validation Reward:    -67.71
# Eval Episode   1 | Steps:  500 | Total Reward:    -71.67
#     Energy Savings (Wh): -23608.59 | Temp Deviation:   0.69 | Cost Savings ($): -2360.86
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -67.22
#     Energy Savings (Wh): -19140.69 | Temp Deviation:   0.74 | Cost Savings ($): -1914.07
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -60.04
#     Energy Savings (Wh): -11937.61 | Temp Deviation:   0.80 | Cost Savings ($): -1193.76
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -63.75
#     Energy Savings (Wh): -15696.06 | Temp Deviation:   0.68 | Cost Savings ($): -1569.61
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -65.01
#     Energy Savings (Wh): -16941.39 | Temp Deviation:   0.72 | Cost Savings ($): -1694.14
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -71.02
#     Energy Savings (Wh): -22969.82 | Temp Deviation:   0.67 | Cost Savings ($): -2296.98
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -64.11
#     Energy Savings (Wh): -16017.10 | Temp Deviation:   0.77 | Cost Savings ($): -1601.71
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -69.70
#     Energy Savings (Wh): -21675.80 | Temp Deviation:   0.62 | Cost Savings ($): -2167.58
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -63.24
#     Energy Savings (Wh): -15143.20 | Temp Deviation:   0.79 | Cost Savings ($): -1514.32
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -67.05
#     Energy Savings (Wh): -18952.72 | Temp Deviation:   0.77 | Cost Savings ($): -1895.27
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -66.28
# Avg Energy Savings (Wh): -18208.30
# Avg Temp Deviation: 0.73
# Avg Cost Savings ($): -1820.83
# Episode  12 | Total Reward:    -68.75 | Avg Loss:   1.2240 | Avg Entropy: 1.3319 | Validation Reward:    -66.28
# Eval Episode   1 | Steps:  500 | Total Reward:    -69.23
#     Energy Savings (Wh): -21216.12 | Temp Deviation:   0.58 | Cost Savings ($): -2121.61
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -59.29
#     Energy Savings (Wh): -11149.88 | Temp Deviation:   0.87 | Cost Savings ($): -1114.99
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -63.52
#     Energy Savings (Wh): -15420.12 | Temp Deviation:   0.80 | Cost Savings ($): -1542.01
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -62.95
#     Energy Savings (Wh): -14835.39 | Temp Deviation:   0.82 | Cost Savings ($): -1483.54
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -61.47
#     Energy Savings (Wh): -13394.55 | Temp Deviation:   0.73 | Cost Savings ($): -1339.45
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -59.98
#     Energy Savings (Wh): -11882.96 | Temp Deviation:   0.78 | Cost Savings ($): -1188.30
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -64.11
#     Energy Savings (Wh): -16029.55 | Temp Deviation:   0.75 | Cost Savings ($): -1602.96
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -60.19
#     Energy Savings (Wh): -12052.45 | Temp Deviation:   0.88 | Cost Savings ($): -1205.25
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -61.61
#     Energy Savings (Wh): -13540.44 | Temp Deviation:   0.71 | Cost Savings ($): -1354.04
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -73.04
#     Energy Savings (Wh): -24987.48 | Temp Deviation:   0.68 | Cost Savings ($): -2498.75
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -63.54
# Avg Energy Savings (Wh): -15450.89
# Avg Temp Deviation: 0.76
# Avg Cost Savings ($): -1545.09
# Episode  13 | Total Reward:    -65.11 | Avg Loss:   1.3445 | Avg Entropy: 1.3320 | Validation Reward:    -63.54
# Eval Episode   1 | Steps:  500 | Total Reward:    -71.63
#     Energy Savings (Wh): -23584.00 | Temp Deviation:   0.67 | Cost Savings ($): -2358.40
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -68.70
#     Energy Savings (Wh): -20637.30 | Temp Deviation:   0.70 | Cost Savings ($): -2063.73
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -65.50
#     Energy Savings (Wh): -17418.32 | Temp Deviation:   0.74 | Cost Savings ($): -1741.83
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -60.37
#     Energy Savings (Wh): -12282.92 | Temp Deviation:   0.75 | Cost Savings ($): -1228.29
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -62.04
#     Energy Savings (Wh): -13963.57 | Temp Deviation:   0.73 | Cost Savings ($): -1396.36
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -62.33
#     Energy Savings (Wh): -14214.07 | Temp Deviation:   0.82 | Cost Savings ($): -1421.41
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -67.95
#     Energy Savings (Wh): -19908.92 | Temp Deviation:   0.64 | Cost Savings ($): -1990.89
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -66.38
#     Energy Savings (Wh): -18281.95 | Temp Deviation:   0.78 | Cost Savings ($): -1828.19
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -63.00
#     Energy Savings (Wh): -14936.32 | Temp Deviation:   0.71 | Cost Savings ($): -1493.63
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -67.55
#     Energy Savings (Wh): -19508.21 | Temp Deviation:   0.66 | Cost Savings ($): -1950.82
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -65.54
# Avg Energy Savings (Wh): -17473.56
# Avg Temp Deviation: 0.72
# Avg Cost Savings ($): -1747.36
# Episode  14 | Total Reward:    -65.33 | Avg Loss:   1.4302 | Avg Entropy: 1.3279 | Validation Reward:    -65.54
# Eval Episode   1 | Steps:  500 | Total Reward:    -61.76
#     Energy Savings (Wh): -13670.51 | Temp Deviation:   0.76 | Cost Savings ($): -1367.05
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -65.41
#     Energy Savings (Wh): -17337.44 | Temp Deviation:   0.72 | Cost Savings ($): -1733.74
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -62.72
#     Energy Savings (Wh): -14619.55 | Temp Deviation:   0.79 | Cost Savings ($): -1461.96
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -67.69
#     Energy Savings (Wh): -19640.76 | Temp Deviation:   0.67 | Cost Savings ($): -1964.08
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -64.04
#     Energy Savings (Wh): -15960.17 | Temp Deviation:   0.73 | Cost Savings ($): -1596.02
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -62.40
#     Energy Savings (Wh): -14325.40 | Temp Deviation:   0.74 | Cost Savings ($): -1432.54
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -64.16
#     Energy Savings (Wh): -16083.30 | Temp Deviation:   0.74 | Cost Savings ($): -1608.33
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -68.33
#     Energy Savings (Wh): -20281.43 | Temp Deviation:   0.68 | Cost Savings ($): -2028.14
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -68.73
#     Energy Savings (Wh): -20699.64 | Temp Deviation:   0.64 | Cost Savings ($): -2069.96
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -64.15
#     Energy Savings (Wh): -16083.16 | Temp Deviation:   0.71 | Cost Savings ($): -1608.32
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -64.94
# Avg Energy Savings (Wh): -16870.14
# Avg Temp Deviation: 0.72
# Avg Cost Savings ($): -1687.01
# Episode  15 | Total Reward:    -61.44 | Avg Loss:   1.1458 | Avg Entropy: 1.3257 | Validation Reward:    -64.94
# Eval Episode   1 | Steps:  500 | Total Reward:    -62.01
#     Energy Savings (Wh): -13905.36 | Temp Deviation:   0.79 | Cost Savings ($): -1390.54
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -65.97
#     Energy Savings (Wh): -17889.68 | Temp Deviation:   0.75 | Cost Savings ($): -1788.97
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -68.79
#     Energy Savings (Wh): -20719.50 | Temp Deviation:   0.72 | Cost Savings ($): -2071.95
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -66.24
#     Energy Savings (Wh): -18205.15 | Temp Deviation:   0.64 | Cost Savings ($): -1820.51
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -62.26
#     Energy Savings (Wh): -14204.00 | Temp Deviation:   0.68 | Cost Savings ($): -1420.40
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -60.72
#     Energy Savings (Wh): -12625.38 | Temp Deviation:   0.77 | Cost Savings ($): -1262.54
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -60.72
#     Energy Savings (Wh): -12604.24 | Temp Deviation:   0.82 | Cost Savings ($): -1260.42
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -56.19
#     Energy Savings (Wh): -8052.10 | Temp Deviation:   0.86 | Cost Savings ($): -805.21
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -66.70
#     Energy Savings (Wh): -18624.18 | Temp Deviation:   0.74 | Cost Savings ($): -1862.42
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -67.58
#     Energy Savings (Wh): -19501.39 | Temp Deviation:   0.74 | Cost Savings ($): -1950.14
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -63.72
# Avg Energy Savings (Wh): -15633.10
# Avg Temp Deviation: 0.75
# Avg Cost Savings ($): -1563.31
# Episode  16 | Total Reward:    -67.99 | Avg Loss:   1.3134 | Avg Entropy: 1.3241 | Validation Reward:    -63.72
# Eval Episode   1 | Steps:  500 | Total Reward:    -64.80
#     Energy Savings (Wh): -16683.16 | Temp Deviation:   0.83 | Cost Savings ($): -1668.32
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -60.93
#     Energy Savings (Wh): -12815.38 | Temp Deviation:   0.82 | Cost Savings ($): -1281.54
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -64.89
#     Energy Savings (Wh): -16832.24 | Temp Deviation:   0.70 | Cost Savings ($): -1683.22
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -62.99
#     Energy Savings (Wh): -14917.13 | Temp Deviation:   0.72 | Cost Savings ($): -1491.71
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -64.68
#     Energy Savings (Wh): -16657.62 | Temp Deviation:   0.62 | Cost Savings ($): -1665.76
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -64.22
#     Energy Savings (Wh): -16104.95 | Temp Deviation:   0.81 | Cost Savings ($): -1610.49
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -63.74
#     Energy Savings (Wh): -15638.55 | Temp Deviation:   0.78 | Cost Savings ($): -1563.85
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -64.09
#     Energy Savings (Wh): -15952.75 | Temp Deviation:   0.87 | Cost Savings ($): -1595.28
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -65.01
#     Energy Savings (Wh): -16958.63 | Temp Deviation:   0.68 | Cost Savings ($): -1695.86
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -65.12
#     Energy Savings (Wh): -17067.34 | Temp Deviation:   0.68 | Cost Savings ($): -1706.73
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -64.05
# Avg Energy Savings (Wh): -15962.77
# Avg Temp Deviation: 0.75
# Avg Cost Savings ($): -1596.28
# Episode  17 | Total Reward:    -61.87 | Avg Loss:   1.1457 | Avg Entropy: 1.3208 | Validation Reward:    -64.05
# Eval Episode   1 | Steps:  500 | Total Reward:    -62.89
#     Energy Savings (Wh): -14826.77 | Temp Deviation:   0.70 | Cost Savings ($): -1482.68
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -61.54
#     Energy Savings (Wh): -13422.16 | Temp Deviation:   0.83 | Cost Savings ($): -1342.22
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -65.70
#     Energy Savings (Wh): -17621.70 | Temp Deviation:   0.74 | Cost Savings ($): -1762.17
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -64.23
#     Energy Savings (Wh): -16123.38 | Temp Deviation:   0.79 | Cost Savings ($): -1612.34
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -57.06
#     Energy Savings (Wh): -8911.22 | Temp Deviation:   0.90 | Cost Savings ($): -891.12
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -58.79
#     Energy Savings (Wh): -10677.64 | Temp Deviation:   0.81 | Cost Savings ($): -1067.76
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -60.21
#     Energy Savings (Wh): -12121.17 | Temp Deviation:   0.75 | Cost Savings ($): -1212.12
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -59.05
#     Energy Savings (Wh): -10968.26 | Temp Deviation:   0.75 | Cost Savings ($): -1096.83
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -56.42
#     Energy Savings (Wh): -8253.31 | Temp Deviation:   0.93 | Cost Savings ($): -825.33
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -60.22
#     Energy Savings (Wh): -12118.02 | Temp Deviation:   0.78 | Cost Savings ($): -1211.80
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -60.61
# Avg Energy Savings (Wh): -12504.36
# Avg Temp Deviation: 0.80
# Avg Cost Savings ($): -1250.44
# Episode  18 | Total Reward:    -65.31 | Avg Loss:   1.1548 | Avg Entropy: 1.3151 | Validation Reward:    -60.61
# Eval Episode   1 | Steps:  500 | Total Reward:    -59.73
#     Energy Savings (Wh): -11592.29 | Temp Deviation:   0.88 | Cost Savings ($): -1159.23
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -58.96
#     Energy Savings (Wh): -10809.08 | Temp Deviation:   0.90 | Cost Savings ($): -1080.91
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -61.10
#     Energy Savings (Wh): -12952.02 | Temp Deviation:   0.89 | Cost Savings ($): -1295.20
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -60.47
#     Energy Savings (Wh): -12385.01 | Temp Deviation:   0.76 | Cost Savings ($): -1238.50
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -60.90
#     Energy Savings (Wh): -12832.27 | Temp Deviation:   0.71 | Cost Savings ($): -1283.23
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -60.43
#     Energy Savings (Wh): -12287.47 | Temp Deviation:   0.89 | Cost Savings ($): -1228.75
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -55.09
#     Energy Savings (Wh): -6979.52 | Temp Deviation:   0.82 | Cost Savings ($): -697.95
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -57.54
#     Energy Savings (Wh): -9348.06 | Temp Deviation:   0.98 | Cost Savings ($): -934.81
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -62.99
#     Energy Savings (Wh): -14924.39 | Temp Deviation:   0.70 | Cost Savings ($): -1492.44
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -58.45
#     Energy Savings (Wh): -10324.43 | Temp Deviation:   0.85 | Cost Savings ($): -1032.44
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -59.57
# Avg Energy Savings (Wh): -11443.45
# Avg Temp Deviation: 0.84
# Avg Cost Savings ($): -1144.35
# Episode  19 | Total Reward:    -60.33 | Avg Loss:   1.1311 | Avg Entropy: 1.3113 | Validation Reward:    -59.57
# Eval Episode   1 | Steps:  500 | Total Reward:    -63.93
#     Energy Savings (Wh): -15814.06 | Temp Deviation:   0.82 | Cost Savings ($): -1581.41
# --------------------------------------------------------------
# Eval Episode   2 | Steps:  500 | Total Reward:    -62.90
#     Energy Savings (Wh): -14898.12 | Temp Deviation:   0.56 | Cost Savings ($): -1489.81
# --------------------------------------------------------------
# Eval Episode   3 | Steps:  500 | Total Reward:    -60.33
#     Energy Savings (Wh): -12227.11 | Temp Deviation:   0.80 | Cost Savings ($): -1222.71
# --------------------------------------------------------------
# Eval Episode   4 | Steps:  500 | Total Reward:    -61.15
#     Energy Savings (Wh): -13076.57 | Temp Deviation:   0.74 | Cost Savings ($): -1307.66
# --------------------------------------------------------------
# Eval Episode   5 | Steps:  500 | Total Reward:    -59.52
#     Energy Savings (Wh): -11406.11 | Temp Deviation:   0.81 | Cost Savings ($): -1140.61
# --------------------------------------------------------------
# Eval Episode   6 | Steps:  500 | Total Reward:    -62.75
#     Energy Savings (Wh): -14635.66 | Temp Deviation:   0.82 | Cost Savings ($): -1463.57
# --------------------------------------------------------------
# Eval Episode   7 | Steps:  500 | Total Reward:    -59.29
#     Energy Savings (Wh): -11220.02 | Temp Deviation:   0.72 | Cost Savings ($): -1122.00
# --------------------------------------------------------------
# Eval Episode   8 | Steps:  500 | Total Reward:    -60.53
#     Energy Savings (Wh): -12455.14 | Temp Deviation:   0.73 | Cost Savings ($): -1245.51
# --------------------------------------------------------------
# Eval Episode   9 | Steps:  500 | Total Reward:    -58.71
#     Energy Savings (Wh): -10616.32 | Temp Deviation:   0.77 | Cost Savings ($): -1061.63
# --------------------------------------------------------------
# Eval Episode  10 | Steps:  500 | Total Reward:    -63.31
#     Energy Savings (Wh): -15240.40 | Temp Deviation:   0.72 | Cost Savings ($): -1524.04
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -61.24
# Avg Energy Savings (Wh): -13158.95
# Avg Temp Deviation: 0.75
# Avg Cost Savings ($): -1315.89
# Episode  20 | Total Reward:    -57.79 | Avg Loss:   1.0859 | Avg Entropy: 1.3077 | Validation Reward:    -61.24
# Eval Episode   1 | Steps:  500 | Total Reward:    -63.30
# ...
# Eval Episode 926 | Steps:  500 | Total Reward:     -7.83
#     Energy Savings (Wh): 41513.98 | Temp Deviation:   3.54 | Cost Savings ($): 4151.40
# --------------------------------------------------------------
# Eval Episode 927 | Steps:  500 | Total Reward:     -7.54
#     Energy Savings (Wh): 41826.98 | Temp Deviation:   3.60 | Cost Savings ($): 4182.70
# --------------------------------------------------------------
# Eval Episode 928 | Steps:  500 | Total Reward:     -7.60
#     Energy Savings (Wh): 41758.81 | Temp Deviation:   3.56 | Cost Savings ($): 4175.88
# --------------------------------------------------------------
# Eval Episode 929 | Steps:  500 | Total Reward:     -7.97
#     Energy Savings (Wh): 41360.20 | Temp Deviation:   3.52 | Cost Savings ($): 4136.02
# --------------------------------------------------------------
# Eval Episode 930 | Steps:  500 | Total Reward:     -7.63
#     Energy Savings (Wh): 41726.98 | Temp Deviation:   3.57 | Cost Savings ($): 4172.70
# --------------------------------------------------------------
# Eval Episode 931 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41530.19 | Temp Deviation:   3.53 | Cost Savings ($): 4153.02
# --------------------------------------------------------------
# Eval Episode 932 | Steps:  500 | Total Reward:     -7.77
#     Energy Savings (Wh): 41573.34 | Temp Deviation:   3.55 | Cost Savings ($): 4157.33
# --------------------------------------------------------------
# Eval Episode 933 | Steps:  500 | Total Reward:     -7.59
#     Energy Savings (Wh): 41763.77 | Temp Deviation:   3.57 | Cost Savings ($): 4176.38
# --------------------------------------------------------------
# Eval Episode 934 | Steps:  500 | Total Reward:     -7.96
#     Energy Savings (Wh): 41376.64 | Temp Deviation:   3.51 | Cost Savings ($): 4137.66
# --------------------------------------------------------------
# Eval Episode 935 | Steps:  500 | Total Reward:     -7.85
#     Energy Savings (Wh): 41498.62 | Temp Deviation:   3.55 | Cost Savings ($): 4149.86
# --------------------------------------------------------------
# Eval Episode 936 | Steps:  500 | Total Reward:     -7.87
#     Energy Savings (Wh): 41476.57 | Temp Deviation:   3.54 | Cost Savings ($): 4147.66
# --------------------------------------------------------------
# Eval Episode 937 | Steps:  500 | Total Reward:     -7.61
#     Energy Savings (Wh): 41738.82 | Temp Deviation:   3.56 | Cost Savings ($): 4173.88
# --------------------------------------------------------------
# Eval Episode 938 | Steps:  500 | Total Reward:     -8.24
#     Energy Savings (Wh): 41076.62 | Temp Deviation:   3.48 | Cost Savings ($): 4107.66
# --------------------------------------------------------------
# Eval Episode 939 | Steps:  500 | Total Reward:     -7.88
#     Energy Savings (Wh): 41458.22 | Temp Deviation:   3.53 | Cost Savings ($): 4145.82
# --------------------------------------------------------------
# Eval Episode 940 | Steps:  500 | Total Reward:     -7.89
#     Energy Savings (Wh): 41449.86 | Temp Deviation:   3.53 | Cost Savings ($): 4144.99
# --------------------------------------------------------------
# Eval Episode 941 | Steps:  500 | Total Reward:     -8.10
#     Energy Savings (Wh): 41203.56 | Temp Deviation:   3.45 | Cost Savings ($): 4120.36
# --------------------------------------------------------------
# Eval Episode 942 | Steps:  500 | Total Reward:     -7.83
#     Energy Savings (Wh): 41505.08 | Temp Deviation:   3.52 | Cost Savings ($): 4150.51
# --------------------------------------------------------------
# Eval Episode 943 | Steps:  500 | Total Reward:     -7.75
#     Energy Savings (Wh): 41587.46 | Temp Deviation:   3.53 | Cost Savings ($): 4158.75
# --------------------------------------------------------------
# Eval Episode 944 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41531.01 | Temp Deviation:   3.54 | Cost Savings ($): 4153.10
# --------------------------------------------------------------
# Eval Episode 945 | Steps:  500 | Total Reward:     -7.84
#     Energy Savings (Wh): 41500.41 | Temp Deviation:   3.53 | Cost Savings ($): 4150.04
# --------------------------------------------------------------
# Eval Episode 946 | Steps:  500 | Total Reward:     -7.99
#     Energy Savings (Wh): 41357.94 | Temp Deviation:   3.55 | Cost Savings ($): 4135.79
# --------------------------------------------------------------
# Eval Episode 947 | Steps:  500 | Total Reward:     -7.70
#     Energy Savings (Wh): 41655.66 | Temp Deviation:   3.57 | Cost Savings ($): 4165.57
# --------------------------------------------------------------
# Eval Episode 948 | Steps:  500 | Total Reward:     -7.77
#     Energy Savings (Wh): 41576.06 | Temp Deviation:   3.55 | Cost Savings ($): 4157.61
# --------------------------------------------------------------
# Eval Episode 949 | Steps:  500 | Total Reward:     -7.68
#     Energy Savings (Wh): 41665.61 | Temp Deviation:   3.55 | Cost Savings ($): 4166.56
# --------------------------------------------------------------
# Eval Episode 950 | Steps:  500 | Total Reward:     -7.86
#     Energy Savings (Wh): 41485.37 | Temp Deviation:   3.53 | Cost Savings ($): 4148.54
# --------------------------------------------------------------
# Eval Episode 951 | Steps:  500 | Total Reward:     -7.66
#     Energy Savings (Wh): 41692.80 | Temp Deviation:   3.55 | Cost Savings ($): 4169.28
# --------------------------------------------------------------
# Eval Episode 952 | Steps:  500 | Total Reward:     -7.71
#     Energy Savings (Wh): 41645.76 | Temp Deviation:   3.56 | Cost Savings ($): 4164.58
# --------------------------------------------------------------
# Eval Episode 953 | Steps:  500 | Total Reward:     -7.75
#     Energy Savings (Wh): 41604.42 | Temp Deviation:   3.56 | Cost Savings ($): 4160.44
# --------------------------------------------------------------
# Eval Episode 954 | Steps:  500 | Total Reward:     -8.09
#     Energy Savings (Wh): 41225.39 | Temp Deviation:   3.49 | Cost Savings ($): 4122.54
# --------------------------------------------------------------
# Eval Episode 955 | Steps:  500 | Total Reward:     -8.01
#     Energy Savings (Wh): 41313.03 | Temp Deviation:   3.50 | Cost Savings ($): 4131.30
# --------------------------------------------------------------
# Eval Episode 956 | Steps:  500 | Total Reward:     -7.72
#     Energy Savings (Wh): 41623.84 | Temp Deviation:   3.53 | Cost Savings ($): 4162.38
# --------------------------------------------------------------
# Eval Episode 957 | Steps:  500 | Total Reward:     -7.85
#     Energy Savings (Wh): 41492.09 | Temp Deviation:   3.52 | Cost Savings ($): 4149.21
# --------------------------------------------------------------
# Eval Episode 958 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41537.26 | Temp Deviation:   3.56 | Cost Savings ($): 4153.73
# --------------------------------------------------------------
# Eval Episode 959 | Steps:  500 | Total Reward:     -7.70
#     Energy Savings (Wh): 41649.53 | Temp Deviation:   3.54 | Cost Savings ($): 4164.95
# --------------------------------------------------------------
# Eval Episode 960 | Steps:  500 | Total Reward:     -7.78
#     Energy Savings (Wh): 41573.06 | Temp Deviation:   3.56 | Cost Savings ($): 4157.31
# --------------------------------------------------------------
# Eval Episode 961 | Steps:  500 | Total Reward:     -7.84
#     Energy Savings (Wh): 41518.69 | Temp Deviation:   3.58 | Cost Savings ($): 4151.87
# --------------------------------------------------------------
# Eval Episode 962 | Steps:  500 | Total Reward:     -7.92
#     Energy Savings (Wh): 41409.31 | Temp Deviation:   3.51 | Cost Savings ($): 4140.93
# --------------------------------------------------------------
# Eval Episode 963 | Steps:  500 | Total Reward:     -7.80
#     Energy Savings (Wh): 41562.18 | Temp Deviation:   3.57 | Cost Savings ($): 4156.22
# --------------------------------------------------------------
# Eval Episode 964 | Steps:  500 | Total Reward:     -7.90
#     Energy Savings (Wh): 41432.71 | Temp Deviation:   3.52 | Cost Savings ($): 4143.27
# --------------------------------------------------------------
# Eval Episode 965 | Steps:  500 | Total Reward:     -7.96
#     Energy Savings (Wh): 41384.34 | Temp Deviation:   3.54 | Cost Savings ($): 4138.43
# --------------------------------------------------------------
# Eval Episode 966 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41541.34 | Temp Deviation:   3.56 | Cost Savings ($): 4154.13
# --------------------------------------------------------------
# Eval Episode 967 | Steps:  500 | Total Reward:     -7.76
#     Energy Savings (Wh): 41585.39 | Temp Deviation:   3.55 | Cost Savings ($): 4158.54
# --------------------------------------------------------------
# Eval Episode 968 | Steps:  500 | Total Reward:     -7.82
#     Energy Savings (Wh): 41517.44 | Temp Deviation:   3.52 | Cost Savings ($): 4151.74
# --------------------------------------------------------------
# Eval Episode 969 | Steps:  500 | Total Reward:     -7.93
#     Energy Savings (Wh): 41407.23 | Temp Deviation:   3.52 | Cost Savings ($): 4140.72
# --------------------------------------------------------------
# Eval Episode 970 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41518.57 | Temp Deviation:   3.50 | Cost Savings ($): 4151.86
# --------------------------------------------------------------
# Eval Episode 971 | Steps:  500 | Total Reward:     -7.94
#     Energy Savings (Wh): 41393.86 | Temp Deviation:   3.51 | Cost Savings ($): 4139.39
# --------------------------------------------------------------
# Eval Episode 972 | Steps:  500 | Total Reward:     -7.74
#     Energy Savings (Wh): 41607.46 | Temp Deviation:   3.55 | Cost Savings ($): 4160.75
# --------------------------------------------------------------
# Eval Episode 973 | Steps:  500 | Total Reward:     -8.00
#     Energy Savings (Wh): 41338.64 | Temp Deviation:   3.52 | Cost Savings ($): 4133.86
# --------------------------------------------------------------
# Eval Episode 974 | Steps:  500 | Total Reward:     -7.67
#     Energy Savings (Wh): 41677.30 | Temp Deviation:   3.55 | Cost Savings ($): 4167.73
# --------------------------------------------------------------
# Eval Episode 975 | Steps:  500 | Total Reward:     -7.89
#     Energy Savings (Wh): 41440.66 | Temp Deviation:   3.51 | Cost Savings ($): 4144.07
# --------------------------------------------------------------
# Eval Episode 976 | Steps:  500 | Total Reward:     -7.75
#     Energy Savings (Wh): 41597.28 | Temp Deviation:   3.54 | Cost Savings ($): 4159.73
# --------------------------------------------------------------
# Eval Episode 977 | Steps:  500 | Total Reward:     -7.89
#     Energy Savings (Wh): 41457.99 | Temp Deviation:   3.55 | Cost Savings ($): 4145.80
# --------------------------------------------------------------
# Eval Episode 978 | Steps:  500 | Total Reward:     -7.95
#     Energy Savings (Wh): 41372.89 | Temp Deviation:   3.50 | Cost Savings ($): 4137.29
# --------------------------------------------------------------
# Eval Episode 979 | Steps:  500 | Total Reward:     -8.01
#     Energy Savings (Wh): 41310.28 | Temp Deviation:   3.48 | Cost Savings ($): 4131.03
# --------------------------------------------------------------
# Eval Episode 980 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41536.82 | Temp Deviation:   3.54 | Cost Savings ($): 4153.68
# --------------------------------------------------------------
# Eval Episode 981 | Steps:  500 | Total Reward:     -8.30
#     Energy Savings (Wh): 41007.36 | Temp Deviation:   3.45 | Cost Savings ($): 4100.74
# --------------------------------------------------------------
# Eval Episode 982 | Steps:  500 | Total Reward:     -8.13
#     Energy Savings (Wh): 41196.09 | Temp Deviation:   3.51 | Cost Savings ($): 4119.61
# --------------------------------------------------------------
# Eval Episode 983 | Steps:  500 | Total Reward:     -7.89
#     Energy Savings (Wh): 41444.13 | Temp Deviation:   3.51 | Cost Savings ($): 4144.41
# --------------------------------------------------------------
# Eval Episode 984 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41533.06 | Temp Deviation:   3.53 | Cost Savings ($): 4153.31
# --------------------------------------------------------------
# Eval Episode 985 | Steps:  500 | Total Reward:     -7.70
#     Energy Savings (Wh): 41638.47 | Temp Deviation:   3.53 | Cost Savings ($): 4163.85
# --------------------------------------------------------------
# Eval Episode 986 | Steps:  500 | Total Reward:     -7.70
#     Energy Savings (Wh): 41645.78 | Temp Deviation:   3.55 | Cost Savings ($): 4164.58
# --------------------------------------------------------------
# Eval Episode 987 | Steps:  500 | Total Reward:     -7.86
#     Energy Savings (Wh): 41468.38 | Temp Deviation:   3.51 | Cost Savings ($): 4146.84
# --------------------------------------------------------------
# Eval Episode 988 | Steps:  500 | Total Reward:     -7.85
#     Energy Savings (Wh): 41490.14 | Temp Deviation:   3.53 | Cost Savings ($): 4149.01
# --------------------------------------------------------------
# Eval Episode 989 | Steps:  500 | Total Reward:     -7.99
#     Energy Savings (Wh): 41335.60 | Temp Deviation:   3.49 | Cost Savings ($): 4133.56
# --------------------------------------------------------------
# Eval Episode 990 | Steps:  500 | Total Reward:     -7.84
#     Energy Savings (Wh): 41502.41 | Temp Deviation:   3.54 | Cost Savings ($): 4150.24
# --------------------------------------------------------------
# Eval Episode 991 | Steps:  500 | Total Reward:     -7.76
#     Energy Savings (Wh): 41581.31 | Temp Deviation:   3.54 | Cost Savings ($): 4158.13
# --------------------------------------------------------------
# Eval Episode 992 | Steps:  500 | Total Reward:     -8.05
#     Energy Savings (Wh): 41273.06 | Temp Deviation:   3.49 | Cost Savings ($): 4127.31
# --------------------------------------------------------------
# Eval Episode 993 | Steps:  500 | Total Reward:     -7.97
#     Energy Savings (Wh): 41367.01 | Temp Deviation:   3.52 | Cost Savings ($): 4136.70
# --------------------------------------------------------------
# Eval Episode 994 | Steps:  500 | Total Reward:     -7.52
#     Energy Savings (Wh): 41841.99 | Temp Deviation:   3.58 | Cost Savings ($): 4184.20
# --------------------------------------------------------------
# Eval Episode 995 | Steps:  500 | Total Reward:     -7.89
#     Energy Savings (Wh): 41440.36 | Temp Deviation:   3.50 | Cost Savings ($): 4144.04
# --------------------------------------------------------------
# Eval Episode 996 | Steps:  500 | Total Reward:     -7.79
#     Energy Savings (Wh): 41551.04 | Temp Deviation:   3.53 | Cost Savings ($): 4155.10
# --------------------------------------------------------------
# Eval Episode 997 | Steps:  500 | Total Reward:     -7.81
#     Energy Savings (Wh): 41544.80 | Temp Deviation:   3.56 | Cost Savings ($): 4154.48
# --------------------------------------------------------------
# Eval Episode 998 | Steps:  500 | Total Reward:     -7.89
#     Energy Savings (Wh): 41456.20 | Temp Deviation:   3.55 | Cost Savings ($): 4145.62
# --------------------------------------------------------------
# Eval Episode 999 | Steps:  500 | Total Reward:     -7.54
#     Energy Savings (Wh): 41820.54 | Temp Deviation:   3.57 | Cost Savings ($): 4182.05
# --------------------------------------------------------------
# Eval Episode 1000 | Steps:  500 | Total Reward:     -7.78
#     Energy Savings (Wh): 41567.05 | Temp Deviation:   3.56 | Cost Savings ($): 4156.70
# --------------------------------------------------------------
#
# Final Average Evaluation Metrics over all evaluation episodes:
# Avg Total Reward: -7.85
# Avg Energy Savings (Wh): 41493.19
# Avg Temp Deviation: 3.53
# Avg Cost Savings ($): 4149.32
# Action counts: [4.9992e+04 6.0000e+00 1.0000e+00 1.0000e+00]
# Action probabilities: [9.9984e-01 1.2000e-04 2.0000e-05 2.0000e-05]
# Sample State: [17.01703704  0.68333333  1.         21.         60.        ]
# Action probabilities: [9.9993742e-01 4.6768469e-05 1.2970958e-05 2.8646973e-06]
